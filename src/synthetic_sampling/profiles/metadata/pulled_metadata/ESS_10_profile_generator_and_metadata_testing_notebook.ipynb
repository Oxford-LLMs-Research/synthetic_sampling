# %% [markdown]
# # Survey Metadata Testing & Profile Generator Demo
#
# **Purpose**: This notebook helps validate survey metadata files and test out the profile generator functionality.
#
# We will use profile generator to create text representation of respondents and conduct various experiments. As such, it is a key project functionality. It would be good to give it a trial run and see if we can spot any bugs before we run the main analysis in January.
#
# It is also crucial we get the metadata files to be as polished as possible. We want to avoid survey/metadata creation artifacts messing up the experiments.
#
# ## What this notebook covers:
# 1. **Metadata Validation** - Check structure, completeness, and common issues
# 2. **Profile Generation** - Generate respondent profiles with varying richness
# 3. **Information Leakage Analysis** - Verify semantic filtering excludes related features
# 4. **Target Question Handling** - Test country-specific options
# 5. **Output Formatting** - Preview different prompt formats
# 6. **Quality Assurance Checklist** - What to look for when testing
#
# ---

# %% [markdown]
# ## **1. Setup**
#
# Run the cells below to import required packages and profile generator.

# %%
# Clone and install the package
# !git clone https://github.com/Oxford-LLMs-Research/synthetic_sampling
# %cd synthetic_sampling
# !pip install -e . -q  # Install in editable mode

# %%
import json
import pandas as pd
import numpy as np
from pathlib import Path
from collections import Counter
import warnings
import sys
import os

sys.path.insert(0, 'src')

# Import the profile generator (adjust path as needed)
from synthetic_sampling.profiles import (
    RespondentProfileGenerator,
    list_profile_formats,
    PROFILE_FORMATS
)

# For pretty printing
from IPython.display import display, Markdown, HTML

print("✓ Imports successful")
# Out:
# ✓ Imports successful

# %% [markdown]
# ---
# **Load Your Metadata**
#
# Replace the path below with your metadata JSON file. The files would be in one of the folders within `/content/synthetic_sampling/src/synthetic_sampling/profiles`.

# %%
# ============================================================
# CONFIGURE YOUR FILES HERE
# ============================================================

METADATA_PATH = "./ess10_profiles_metadata.json"  # <-- UPDATE THIS

# Load metadata
with open(METADATA_PATH, 'r', encoding='utf-8') as f:
    metadata = json.load(f)

print(f"✓ Loaded metadata from: {METADATA_PATH}")
print(f"  Number of sections: {len(metadata)}")
print(f"  Sections: {list(metadata.keys())}")
# Out:
# ✓ Loaded metadata from: ./ess10_profiles_metadata.json
#   Number of sections: 12
#   Sections: ['demographics', 'media_information_sources', 'other', 'trust_in_social_groups', 'politics', 'governance', 'civic_engagement', 'trust_in_institutions', 'political_affiliation', 'economic_outlook', 'climate_change', 'covid']

# %%
# this cell is optional; it is to pull out survey csv files from gdrive.

# mount_point = '/content/drive'
# from google.colab import drive
# drive.mount(mount_point)

# %%
# SURVEY_DATA_PATH = "/content/drive/MyDrive/Oxford LLMs Research/surveys/WVS/WVS_2017_22.csv"  # <-- UPDATE THISSURVEY_DATA_PATH = "/content/drive/MyDrive/Oxford LLMs Research/surveys/WVS/WVS_2017_22.csv"  # <-- UPDATE THIS

# load survey csv's
# wvs_data = pd.read_csv("/content/drive/MyDrive/Oxford LLMs Research/surveys/WVS/WVS_2017_22.csv")
ess_data = pd.read_csv("../../../../../data/ess//ESS10.csv", low_memory = False)

# %% [markdown]
# ## **2. Metadata Validation**

# %% [markdown]
# ---
# **Metadata Structure Validation**
#
# This section checks that your metadata follows the expected structure.

# %%
#@title metadata validation
"""
Enhanced Survey Metadata Validation for LLM-based Survey Response Prediction

This module validates survey metadata structure and detects common survey artifacts
that need to be cleaned or reformulated before use with LLMs.

Artifact Categories Detected:
1. Interviewer instructions (SHOWCARD, Do not read, etc.)
2. Placeholders in question text ([president], [country], [year], etc.)
3. Binary marking patterns (Marked/Not marked, Yes/No checkboxes)
4. Skip/routing logic artifacts (Go to Q__, If respondent answers...)
5. Response code artifacts (Code 7, Code 8, etc.)
6. Administrative/meta artifacts (Interview Record, Post-code, etc.)
7. Scale presentation artifacts (Likert abbreviations like SA, SWA, SWD, SD)
8. Multi-select/checkbox battery artifacts
9. Country-specific placeholder patterns
10. Numeric code artifacts in values (97, 98, 99 for DK/Refuse)

Author: Research Team
Purpose: Pre-processing validation for LLM survey prediction experiments
"""

from collections import Counter
import re
from typing import Dict, List, Tuple, Any, Optional
from dataclasses import dataclass, field


@dataclass
class ArtifactMatch:
    """Represents a detected artifact in survey metadata."""
    artifact_type: str
    location: str  # section/variable path
    field: str  # 'question', 'description', 'values', etc.
    matched_text: str
    pattern_name: str
    severity: str  # 'critical', 'warning', 'info'
    suggestion: Optional[str] = None


@dataclass
class ValidationReport:
    """Complete validation report for survey metadata."""
    critical: List[str] = field(default_factory=list)
    warnings: List[str] = field(default_factory=list)
    info: List[str] = field(default_factory=list)
    artifacts: List[ArtifactMatch] = field(default_factory=list)
    statistics: Dict[str, Any] = field(default_factory=dict)


# =============================================================================
# ARTIFACT DETECTION PATTERNS
# =============================================================================

# 1. Interviewer instruction patterns
INTERVIEWER_INSTRUCTION_PATTERNS = [
    # Showcard instructions
    (r'\(?\s*SHOWCARD\s*\)?', 'showcard_instruction'),
    (r'\[?\s*SHOW\s*CARD\s*\]?', 'showcard_instruction'),

    # Do not read instructions
    (r'\[?\s*[Dd]o\s*not\s*read\s*[:\]]?', 'do_not_read'),
    (r'\[?\s*DO\s*NOT\s*READ\s*[:\]]?', 'do_not_read'),
    (r'\(?\s*[Dd]o\s*not\s*read\s*[:\)]?', 'do_not_read'),

    # Interviewer notes
    (r'\[?\s*[Ii]nterviewer\s*:?\s*[^\]]*\]?', 'interviewer_note'),
    (r'\[?\s*INTERVIEWER\s*:?\s*[^\]]*\]?', 'interviewer_note'),
    (r'\[?\s*[Nn]ote\s*:?\s*[^\]]*\]?', 'note_instruction'),
    (r'\[?\s*NOTE\s*:?\s*[^\]]*\]?', 'note_instruction'),
    (r'\[?\s*[Ii]nstruction\s*:?\s*[^\]]*\]?', 'instruction_note'),

    # Read aloud instructions (including READ EACH ITEM from Latinobarómetro)
    (r'\[?\s*[Rr]ead\s*out\s*[^\]]*\]?', 'read_aloud'),
    (r'\[?\s*READ\s*OUT\s*[^\]]*\]?', 'read_aloud'),
    (r'\(?\s*[Rr]ead\s*out\s*options?\s*\)?', 'read_aloud'),
    (r'READ\s*EACH\s*ITEM', 'read_aloud'),

    # One answer only
    (r'\(?\s*ONE\s*ANSWER\s*ONLY\s*\)?', 'single_answer_instruction'),
    (r'\(?\s*[Oo]ne\s*answer\s*only\s*\)?', 'single_answer_instruction'),
    (r'\[?\s*[Mm]ultiple\s*answers?\s*allowed\s*\]?', 'multiple_answer_instruction'),

    # Probe instructions
    (r'\[?\s*[Pp]robe\s*[^\]]*\]?', 'probe_instruction'),
    (r'\[?\s*PROBE\s*[^\]]*\]?', 'probe_instruction'),

    # Optional question markers
    (r'<\s*[Oo]ptional\s*>', 'optional_marker'),
    (r'<\s*OPTIONAL\s*>', 'optional_marker'),

    # GBS markers (Global Barometer Survey standard questions)
    (r'\[?\s*GBS\s*\]?', 'gbs_marker'),

    # For coding only instructions (Latinobarómetro pattern)
    (r'FOR\s*CODING\s*ONLY', 'coding_only_instruction'),
    (r'[Ff]or\s*coding\s*only', 'coding_only_instruction'),

    # If volunteered pattern (Latinobarómetro)
    (r'\(?\s*if\s*volunteered\s*\)?', 'if_volunteered'),
    (r'\(?\s*IF\s*VOLUNTEERED\s*\)?', 'if_volunteered'),

    # Assessment/observation instructions (for interviewer to fill)
    (r'ASSESSMENT\s*OF\s*THE\s*INTERVIEWEE', 'interviewer_assessment'),
    (r'[Tt]ake\s*as\s*reference', 'interviewer_assessment'),
]

# 2. Placeholder patterns (need country/context-specific filling)
PLACEHOLDER_PATTERNS = [
    # Bracketed placeholders - various styles
    (r'\[country\s*name?\]', 'country_placeholder'),
    (r'\[Country\s*Name?\]', 'country_placeholder'),
    (r'\[COUNTRY\]', 'country_placeholder'),
    (r'\[country\]', 'country_placeholder'),
    (r'\[Country\s*X?\]', 'country_placeholder'),
    # Parenthetical country placeholders (Latinobarómetro style)
    (r'\(country\)', 'country_placeholder'),
    (r'\(COUNTRY\)', 'country_placeholder'),
    (r'\(Country\)', 'country_placeholder'),
    # Country possessive forms
    (r'\(COUNTRY´S\)', 'country_placeholder'),
    (r'\(COUNTRY\'S\)', 'country_placeholder'),
    (r"\(country's\)", 'country_placeholder'),

    # Leader/official placeholders
    (r'\[president\]', 'leader_placeholder'),
    (r'\[President\]', 'leader_placeholder'),
    (r'\[prime\s*minister\]', 'leader_placeholder'),
    (r'\[Prime\s*Minister\]', 'leader_placeholder'),
    (r'\[PM\]', 'leader_placeholder'),
    (r'\[name\s*of\s*president[^\]]*\]', 'leader_placeholder'),
    (r'\[current\s*ruling[^\]]*\]', 'leader_placeholder'),
    # Latinobarómetro style: (president´s name)
    (r"\(president['\u00b4\u2019]?s?\s*name\)", 'leader_placeholder'),
    (r"\(PRESIDENT['\u00b4\u2019]?S?\s*NAME\)", 'leader_placeholder'),

    # Year placeholders
    (r'\[year\]', 'year_placeholder'),
    (r'\[Year\]', 'year_placeholder'),
    (r'\[YEAR\]', 'year_placeholder'),
    (r'\[20\d{2}\]', 'year_placeholder'),

    # Institution placeholders
    (r'\[specify\s*institution[^\]]*\]', 'institution_placeholder'),
    (r'\[name\s*of\s*institution[^\]]*\]', 'institution_placeholder'),
    (r'\[election\s*commission[^\]]*\]', 'institution_placeholder'),

    # Party placeholders - only match generic placeholder patterns like "Party A", "Party B"
    # NOT legitimate party names like "Republican Party of Namibia"
    # Require: standalone "Party X" at word boundary, or bracketed, or followed by ellipsis
    (r'\bParty\s+[A-Z]\s*$', 'party_placeholder'),  # "Party A" at end of string
    (r'\bParty\s+[A-Z]\s*[,\.]', 'party_placeholder'),  # "Party A," or "Party A."
    (r'\bParty\s+[A-Z]\s+Party\s+[A-Z]', 'party_placeholder'),  # "Party A Party B" pattern
    (r'\[Party\s*[A-Z]\]', 'party_placeholder'),  # "[Party A]" bracketed
    (r'Party\s+[A-Z]\.{2,}', 'party_placeholder'),  # "Party A..." with ellipsis
    (r'\[country-specific[^\]]*\]', 'country_specific_placeholder'),
    (r'\[use\s*two-digit\s*code[^\]]*\]', 'coding_instruction_placeholder'),

    # Generic fill-in placeholders
    (r'\[fill\s*in[^\]]*\]', 'fill_in_placeholder'),
    (r'\[specify[^\]]*\]', 'specify_placeholder'),
    (r'___+', 'blank_line_placeholder'),
    (r'\(\s*\)', 'empty_parens_placeholder'),

    # Capital city placeholder
    (r'\[in\s*capital\s*city\]', 'location_placeholder'),

    # Item placeholder (Latinobarómetro battery questions)
    (r'\[ITEM\]', 'item_placeholder'),
    (r'\[item\]', 'item_placeholder'),

    # National/local placeholders (Latinobarómetro)
    (r'\(NATIONAL\)', 'national_placeholder'),
    (r'\(national\)', 'national_placeholder'),
]

# 3. Skip/routing logic patterns
SKIP_LOGIC_PATTERNS = [
    (r'[Gg]o\s*to\s*[Qq]\.?\s*\d+', 'skip_instruction'),
    (r'GO\s*TO\s*Q\.?\s*\d+', 'skip_instruction'),
    (r'\[?\s*[Ss]kip\s*to\s*[Qq]\.?\s*\d+\s*\]?', 'skip_instruction'),
    (r'[Gg]o\s*to\s*INTRO', 'skip_instruction'),
    (r'GO\s*TO\s*INTRO', 'skip_instruction'),
    (r'[Ii]f\s*the\s*respondent\s*answers?', 'conditional_routing'),
    (r'IF\s*THE\s*RESPONDENT', 'conditional_routing'),
    (r'\[?\s*[Ll]ogical\s*check\s*with\s*[Qq]\.?\s*\d+\s*\]?', 'logic_check'),
    (r'[Ff]or\s*those\s*go\s*to', 'routing_note'),
]

# 4. Response code artifacts
RESPONSE_CODE_PATTERNS = [
    # Code references in text
    (r'[Cc]ode\s*\d+\s*:', 'code_reference'),
    (r'\(\s*[Cc]ode\s*\d+\s*[:\)]', 'code_reference'),
    (r'[Cc]ode\s*\d+-\d+', 'code_range'),

    # Post-coding instructions
    (r'\(?\s*[Pp]ost[\s-]*[Cc]ode\s*\)?', 'post_code_instruction'),
    (r'\(?\s*POST[\s-]*CODE\s*\)?', 'post_code_instruction'),

    # Pre-coded instructions
    (r'open-ended,?\s*pre-coded', 'precoded_instruction'),
    (r'\(?\s*[Rr]ecord\s*[Vv]erbatim[^\)]*\)?', 'verbatim_instruction'),
]

# 5. Scale abbreviation patterns (Likert scales)
SCALE_ABBREVIATION_PATTERNS = [
    # Header row abbreviations
    (r'\bSA\b.*\bSWA\b.*\bSWD\b.*\bSD\b', 'likert_header_abbreviations'),
    (r'\bDU\b.*\bCC\b.*\bDA\b', 'response_code_abbreviations'),

    # Individual abbreviations that might appear in values
    (r'^SA$', 'strongly_agree_abbrev'),
    (r'^SWA$', 'somewhat_agree_abbrev'),
    (r'^SWD$', 'somewhat_disagree_abbrev'),
    (r'^SD$', 'strongly_disagree_abbrev'),
    (r'^DU$', 'dont_understand_abbrev'),
    (r'^CC$', 'cant_choose_abbrev'),
    (r'^DA$', 'decline_answer_abbrev'),
    (r'^DK$', 'dont_know_abbrev'),
]

# 6. Binary/checkbox marking patterns
BINARY_MARKING_PATTERNS = [
    (r'[Mm]arked', 'marked_response'),
    (r'[Nn]ot\s*[Mm]arked', 'not_marked_response'),
    (r'^1$.*^2$', 'binary_yes_no_codes'),  # Simple 1/2 coding
    (r'[Cc]hecked', 'checkbox_response'),
    (r'[Uu]nchecked', 'checkbox_response'),
    (r'[Tt]icked', 'checkbox_response'),
]

# 7. Multi-select battery patterns
MULTISELECT_PATTERNS = [
    (r'\d+[a-z]\.\s', 'sub_question_numbering'),
    (r'[Qq]\d+[a-z]', 'sub_question_reference'),
    (r'First\s*[Oo]rganization', 'multi_response_first'),
    (r'Second\s*[Oo]rganization', 'multi_response_second'),
    (r'Third\s*[Oo]rganization', 'multi_response_third'),
]

# 8. Administrative/meta patterns
ADMINISTRATIVE_PATTERNS = [
    (r'[Ii]nterview\s*[Nn]o\.?', 'interview_number'),
    (r"[Ii]nterviewer['\u2019]?s?\s*number", 'interviewer_id'),
    (r'[Dd]ate\s*of\s*[Ii]nterview', 'interview_date'),
    (r'[Pp]ostal\s*[Zz]ip\s*[Cc]ode', 'postal_code'),
    (r'TO\s*BE\s*FILLED\s*IN\s*BY', 'admin_instruction'),
    (r'[Ff]illed\s*in\s*by\s*the\s*interviewer', 'admin_instruction'),
]

# 9. Special response value patterns (missing data codes)
SPECIAL_VALUE_PATTERNS = [
    # Standard missing data codes
    (r'^97$', 'do_not_understand_code'),
    (r'^98$', 'cant_choose_code'),
    (r'^99$', 'decline_to_answer_code'),
    (r'^0$', 'not_applicable_code'),
    (r'^7$', 'dont_understand_single_digit'),
    (r'^8$', 'cant_choose_single_digit'),
    (r'^9$', 'decline_answer_single_digit'),

    # Ranges indicating special codes
    (r'^9[0-9]$', 'special_code_90s'),
]

# 10. Missing data label patterns (text patterns indicating non-response)
MISSING_DATA_LABEL_PATTERNS = [
    # DNK/DK patterns (Don't Know)
    (r'\bDNK\b', 'dont_know_abbreviation'),
    (r'\bDK\b', 'dont_know_abbreviation'),
    (r'\bDKN\b', 'dont_know_abbreviation'),
    (r"[Dd]on['\u2019]?t\s*[Kk]now", 'dont_know_label'),

    # NA patterns (No Answer / Not Applicable)
    (r'\bNA\b', 'no_answer_abbreviation'),
    (r'\bDNA\b', 'no_answer_abbreviation'),
    (r'\bDNK/NA\b', 'combined_dk_na'),
    (r'\bDK/NA\b', 'combined_dk_na'),
    (r'\bDNK/DNA\b', 'combined_dk_na'),

    # Not applicable patterns
    (r'[Nn]ot\s*[Aa]pplicable', 'not_applicable_label'),
    (r'[Nn]o\s*[Aa]nswer', 'no_answer_label'),
    (r'[Nn]o\s*[Dd]ata', 'no_data_label'),
]

# 11. Column position references (SPSS-style codebook artifacts)
COLUMN_POSITION_PATTERNS = [
    # Column position in parentheses like (60) or (63-64)
    (r'\(\d{1,3}\)$', 'column_position_single'),
    (r'\(\d{1,3}-\d{1,3}\)$', 'column_position_range'),
    # SPSS variable position notation
    (r'\d+-\d+\s*$', 'position_notation'),
]

# 12. Ranking/priority question patterns (multi-part questions)
RANKING_QUESTION_PATTERNS = [
    # "Which is second most important" patterns
    (r'[Ww]hich\s*would\s*be\s*second', 'ranking_second'),
    (r'[Ss]econd\s*most\s*important', 'ranking_second'),
    (r'[Ff]irst\s*most\s*important', 'ranking_first'),
    (r'[Tt]hird\s*most\s*important', 'ranking_third'),
    # Sequential question indicators
    (r'\.\d+\.\s', 'sequential_question_number'),
]

# 13. Recode/derived variable patterns
RECODE_PATTERNS = [
    (r'RECODE\s*OF', 'recode_variable'),
    (r'RECODED', 'recode_variable'),
    (r'[Rr]ecode\s*of', 'recode_variable'),
    # Local/weight variables
    (r'LOCAL\s*VARIABLE', 'local_variable'),
    (r'\bWT\b\.?\s*[Ww]eight', 'weight_variable'),
]

# 14. Survey series identifiers in variable names
SURVEY_SERIES_PATTERNS = [
    # Common suffixes indicating survey standardization
    (r'ST(?:GBS)?\.', 'standard_question_marker'),  # ST or STGBS prefix
    (r'GBS\.', 'global_barometer_marker'),
    (r'WVS', 'world_values_survey_marker'),
    (r'CSN?\.', 'country_specific_marker'),
    (r'INN?\.', 'innovation_module_marker'),
    (r'SDN\.', 'special_module_marker'),
]

# 10. Question text quality issues
QUESTION_QUALITY_PATTERNS = [
    # Questions that are too short
    (r'^.{1,10}$', 'very_short_question'),

    # Questions with just variable codes (but not common short words)
    # Must be at least 2 chars and look like a variable code (e.g., Q1, SE3, ABC123)
    (r'^[A-Z]{2,}\d+$', 'variable_code_only'),
    (r'^[A-Z]\d{2,}$', 'variable_code_only'),

    # Questions referencing other questions
    (r'[Aa]nswer\s*in\s*[Qq]\.?\s*\d+', 'answer_reference'),
    (r'[Ss]ee\s*[Qq]\.?\s*\d+', 'question_reference'),

    # System/form artifacts
    (r'for\s*presidential\s*system', 'system_conditional'),
    (r'for\s*parliamentary\s*system', 'system_conditional'),
]


def compile_patterns(pattern_list: List[Tuple[str, str]]) -> List[Tuple[re.Pattern, str]]:
    """Compile regex patterns for efficiency."""
    return [(re.compile(pattern, re.IGNORECASE), name) for pattern, name in pattern_list]


# Compile all pattern groups
COMPILED_PATTERNS = {
    'interviewer_instructions': compile_patterns(INTERVIEWER_INSTRUCTION_PATTERNS),
    'placeholders': compile_patterns(PLACEHOLDER_PATTERNS),
    'skip_logic': compile_patterns(SKIP_LOGIC_PATTERNS),
    'response_codes': compile_patterns(RESPONSE_CODE_PATTERNS),
    'scale_abbreviations': compile_patterns(SCALE_ABBREVIATION_PATTERNS),
    'binary_marking': compile_patterns(BINARY_MARKING_PATTERNS),
    'multiselect': compile_patterns(MULTISELECT_PATTERNS),
    'administrative': compile_patterns(ADMINISTRATIVE_PATTERNS),
    'special_values': compile_patterns(SPECIAL_VALUE_PATTERNS),
    'question_quality': compile_patterns(QUESTION_QUALITY_PATTERNS),
    'missing_data_labels': compile_patterns(MISSING_DATA_LABEL_PATTERNS),
    'column_positions': compile_patterns(COLUMN_POSITION_PATTERNS),
    'ranking_questions': compile_patterns(RANKING_QUESTION_PATTERNS),
    'recode_variables': compile_patterns(RECODE_PATTERNS),
    'survey_series': compile_patterns(SURVEY_SERIES_PATTERNS),
}

# Severity mapping for artifact types
SEVERITY_MAP = {
    # Critical - must fix before use
    'country_placeholder': 'critical',
    'leader_placeholder': 'critical',
    'year_placeholder': 'critical',
    'institution_placeholder': 'critical',
    'party_placeholder': 'critical',
    'country_specific_placeholder': 'critical',
    'fill_in_placeholder': 'critical',
    'specify_placeholder': 'critical',
    'blank_line_placeholder': 'critical',
    'variable_code_only': 'critical',
    'item_placeholder': 'critical',
    'national_placeholder': 'critical',

    # Warning - should review/clean
    'showcard_instruction': 'warning',
    'do_not_read': 'warning',
    'interviewer_note': 'warning',
    'instruction_note': 'warning',
    'read_aloud': 'warning',
    'single_answer_instruction': 'warning',
    'multiple_answer_instruction': 'warning',
    'probe_instruction': 'warning',
    'skip_instruction': 'warning',
    'conditional_routing': 'warning',
    'logic_check': 'warning',
    'code_reference': 'warning',
    'post_code_instruction': 'warning',
    'precoded_instruction': 'warning',
    'verbatim_instruction': 'warning',
    'marked_response': 'warning',
    'not_marked_response': 'warning',
    'checkbox_response': 'warning',
    'system_conditional': 'warning',
    'answer_reference': 'warning',
    'question_reference': 'warning',
    'location_placeholder': 'warning',
    'coding_instruction_placeholder': 'warning',
    'coding_only_instruction': 'warning',
    'if_volunteered': 'warning',
    'interviewer_assessment': 'warning',
    'recode_variable': 'warning',
    'local_variable': 'warning',
    'weight_variable': 'warning',

    # Info - awareness only
    'optional_marker': 'info',
    'gbs_marker': 'info',
    'note_instruction': 'info',
    'sub_question_numbering': 'info',
    'sub_question_reference': 'info',
    'multi_response_first': 'info',
    'multi_response_second': 'info',
    'multi_response_third': 'info',
    'do_not_understand_code': 'info',
    'cant_choose_code': 'info',
    'decline_to_answer_code': 'info',
    'not_applicable_code': 'info',
    'dont_understand_single_digit': 'info',
    'cant_choose_single_digit': 'info',
    'decline_answer_single_digit': 'info',
    'special_code_90s': 'info',
    'very_short_question': 'info',
    'routing_note': 'info',
    'empty_parens_placeholder': 'info',
    'admin_instruction': 'info',
    'interview_number': 'info',
    'interviewer_id': 'info',
    'interview_date': 'info',
    'postal_code': 'info',
    'binary_yes_no_codes': 'info',
    'likert_header_abbreviations': 'info',
    'response_code_abbreviations': 'info',
    # Missing data labels
    'dont_know_abbreviation': 'info',
    'dont_know_label': 'info',
    'no_answer_abbreviation': 'info',
    'combined_dk_na': 'info',
    'not_applicable_label': 'info',
    'no_answer_label': 'info',
    'no_data_label': 'info',
    # Column positions
    'column_position_single': 'info',
    'column_position_range': 'info',
    'position_notation': 'info',
    # Ranking questions
    'ranking_second': 'info',
    'ranking_first': 'info',
    'ranking_third': 'info',
    'sequential_question_number': 'info',
    # Survey series markers
    'standard_question_marker': 'info',
    'global_barometer_marker': 'info',
    'world_values_survey_marker': 'info',
    'country_specific_marker': 'info',
    'innovation_module_marker': 'info',
    'special_module_marker': 'info',
}


def detect_artifacts_in_text(
    text: str,
    location: str,
    field_name: str
) -> List[ArtifactMatch]:
    """Detect all artifacts in a given text string."""
    artifacts = []

    if not text or not isinstance(text, str):
        return artifacts

    for category, patterns in COMPILED_PATTERNS.items():
        for pattern, pattern_name in patterns:
            matches = pattern.finditer(text)
            for match in matches:
                severity = SEVERITY_MAP.get(pattern_name, 'info')
                suggestion = get_suggestion(pattern_name, match.group())

                artifacts.append(ArtifactMatch(
                    artifact_type=category,
                    location=location,
                    field=field_name,
                    matched_text=match.group(),
                    pattern_name=pattern_name,
                    severity=severity,
                    suggestion=suggestion
                ))

    return artifacts


def get_suggestion(pattern_name: str, matched_text: str) -> str:
    """Generate a suggestion for fixing the artifact."""
    suggestions = {
        # Placeholders
        'country_placeholder': 'Replace with actual country name for each survey wave',
        'leader_placeholder': 'Replace with actual leader title/name (e.g., "the president" or specific name)',
        'year_placeholder': 'Replace with actual election/reference year',
        'institution_placeholder': 'Replace with actual institution name',
        'party_placeholder': 'Use country-specific party names from survey codebook',
        'fill_in_placeholder': 'Remove or replace with appropriate context',
        'blank_line_placeholder': 'Remove blank lines or convert to natural language',

        # Interviewer instructions
        'showcard_instruction': 'Remove SHOWCARD reference - not relevant for LLM prompting',
        'do_not_read': 'Consider whether these options should be included in LLM prompt',
        'interviewer_note': 'Remove interviewer instructions',
        'read_aloud': 'Remove read-aloud instructions',
        'probe_instruction': 'Remove probe instructions',

        # Response artifacts
        'marked_response': 'Convert to Yes/No or actual response labels',
        'not_marked_response': 'Convert to Yes/No or actual response labels',
        'checkbox_response': 'Convert to meaningful response labels',

        # Skip logic
        'skip_instruction': 'Remove skip logic - not applicable for independent question prompting',
        'conditional_routing': 'Document skip conditions separately; remove from question text',

        # Codes
        'code_reference': 'Remove code references from question/option text',
        'do_not_understand_code': 'Consider whether to include as valid response option',
        'cant_choose_code': 'Consider whether to include as valid response option',
        'decline_to_answer_code': 'Consider whether to include as valid response option',
    }

    return suggestions.get(pattern_name, 'Review and clean as appropriate')


def validate_metadata_structure(metadata: dict) -> ValidationReport:
    """
    Validate metadata structure and detect artifacts.

    Expected structure:
    {
        "section_name": {
            "VARIABLE_CODE": {
                "description": str,
                "question": str,
                "values": {"code": "label", ...}
            },
            ...
        },
        ...
    }

    Returns:
        ValidationReport with issues, artifacts, and statistics
    """
    report = ValidationReport()
    required_fields = ['description', 'question', 'values']
    all_variables = []
    total_value_codes = 0
    artifact_counts = Counter()

    for section_name, section_data in metadata.items():
        if not isinstance(section_data, dict):
            report.critical.append(
                f"Section '{section_name}' is not a dict (got {type(section_data).__name__})"
            )
            continue

        for var_code, var_data in section_data.items():
            all_variables.append(var_code)
            location = f"[{section_name}] {var_code}"

            if not isinstance(var_data, dict):
                report.critical.append(
                    f"{location} is not a dict"
                )
                continue

            # Check required fields
            for field in required_fields:
                if field not in var_data:
                    report.critical.append(
                        f"{location} missing required field: '{field}'"
                    )

            # Validate and check description field
            if 'description' in var_data:
                desc = var_data['description']
                if not isinstance(desc, str):
                    report.warnings.append(
                        f"{location} description is not a string"
                    )
                else:
                    # Check for artifacts in description
                    desc_artifacts = detect_artifacts_in_text(desc, location, 'description')
                    report.artifacts.extend(desc_artifacts)
                    for a in desc_artifacts:
                        artifact_counts[a.pattern_name] += 1

            # Validate and check question field
            if 'question' in var_data:
                q = var_data['question']
                if not isinstance(q, str):
                    report.warnings.append(
                        f"{location} question is not a string"
                    )
                elif len(q) < 10:
                    report.warnings.append(
                        f"{location} question seems too short: '{q}'"
                    )
                else:
                    # Check for artifacts in question text
                    q_artifacts = detect_artifacts_in_text(q, location, 'question')
                    report.artifacts.extend(q_artifacts)
                    for a in q_artifacts:
                        artifact_counts[a.pattern_name] += 1

            # Validate and check values field
            if 'values' in var_data:
                values = var_data['values']
                if not isinstance(values, dict):
                    report.critical.append(
                        f"{location} values is not a dict"
                    )
                elif len(values) == 0:
                    report.warnings.append(
                        f"{location} has empty values dict"
                    )
                else:
                    total_value_codes += len(values)

                    # Check for non-string keys
                    non_str_keys = [k for k in values.keys() if not isinstance(k, str)]
                    if non_str_keys:
                        report.warnings.append(
                            f"{location} has non-string value codes: {non_str_keys}"
                        )

                    # Check for artifacts in value labels
                    for code, label in values.items():
                        if isinstance(label, str):
                            # Check the value label
                            v_artifacts = detect_artifacts_in_text(
                                label, location, f'values[{code}]'
                            )
                            report.artifacts.extend(v_artifacts)
                            for a in v_artifacts:
                                artifact_counts[a.pattern_name] += 1

                            # Also check the code itself (as string)
                            code_artifacts = detect_artifacts_in_text(
                                str(code), location, f'value_code[{code}]'
                            )
                            # Filter to only special value patterns
                            code_artifacts = [
                                a for a in code_artifacts
                                if a.artifact_type == 'special_values'
                            ]
                            report.artifacts.extend(code_artifacts)
                            for a in code_artifacts:
                                artifact_counts[a.pattern_name] += 1

    # Check for duplicate variable codes
    duplicates = [v for v, count in Counter(all_variables).items() if count > 1]
    if duplicates:
        report.critical.append(
            f"Duplicate variable codes found: {duplicates}"
        )

    # Compile statistics
    report.statistics = {
        'total_sections': len(metadata),
        'total_variables': len(all_variables),
        'total_value_codes': total_value_codes,
        'variables_per_section': {
            section: len(vars_) for section, vars_ in metadata.items()
            if isinstance(vars_, dict)
        },
        'artifact_counts': dict(artifact_counts),
        'artifacts_by_severity': {
            'critical': len([a for a in report.artifacts if a.severity == 'critical']),
            'warning': len([a for a in report.artifacts if a.severity == 'warning']),
            'info': len([a for a in report.artifacts if a.severity == 'info']),
        },
        'artifacts_by_type': Counter(a.artifact_type for a in report.artifacts),
    }

    # Generate summary info
    report.info.append(f"Total sections: {report.statistics['total_sections']}")
    report.info.append(f"Total variables: {report.statistics['total_variables']}")
    report.info.append(f"Total value codes: {report.statistics['total_value_codes']}")

    for section, count in report.statistics['variables_per_section'].items():
        report.info.append(f"  - {section}: {count} variables")

    return report


def print_validation_report(report: ValidationReport, show_artifacts: bool = True):
    """Pretty-print the validation report."""
    print("=" * 70)
    print("METADATA VALIDATION REPORT")
    print("=" * 70)

    # Critical issues
    if report.critical:
        print("\n❌ CRITICAL ISSUES (must fix):")
        for issue in report.critical:
            print(f"   • {issue}")
    else:
        print("\n✓ No critical structural issues found")

    # Warnings
    if report.warnings:
        print("\n⚠️  WARNINGS (should review):")
        for issue in report.warnings[:20]:  # Limit output
            print(f"   • {issue}")
        if len(report.warnings) > 20:
            print(f"   ... and {len(report.warnings) - 20} more warnings")
    else:
        print("\n✓ No warnings")

    # Artifact summary
    if report.artifacts:
        print("\n🔍 ARTIFACT DETECTION SUMMARY:")
        print(f"   Total artifacts found: {len(report.artifacts)}")
        print(f"   - Critical: {report.statistics['artifacts_by_severity']['critical']}")
        print(f"   - Warning: {report.statistics['artifacts_by_severity']['warning']}")
        print(f"   - Info: {report.statistics['artifacts_by_severity']['info']}")

        print("\n   By category:")
        for cat, count in report.statistics['artifacts_by_type'].most_common():
            print(f"   - {cat}: {count}")

        if show_artifacts:
            # Show critical artifacts
            critical_artifacts = [a for a in report.artifacts if a.severity == 'critical']
            if critical_artifacts:
                print("\n   🚨 CRITICAL ARTIFACTS (require fixing):")
                for a in critical_artifacts[:15]:
                    print(f"      [{a.location}] {a.field}")
                    print(f"         Pattern: {a.pattern_name}")
                    print(f"         Matched: '{a.matched_text}'")
                    print(f"         Suggestion: {a.suggestion}")
                if len(critical_artifacts) > 15:
                    print(f"      ... and {len(critical_artifacts) - 15} more critical artifacts")

            # Show sample warning artifacts
            warning_artifacts = [a for a in report.artifacts if a.severity == 'warning']
            if warning_artifacts:
                print("\n   ⚠️  SAMPLE WARNING ARTIFACTS:")
                for a in warning_artifacts[:10]:
                    print(f"      [{a.location}] {a.field}: '{a.matched_text}' ({a.pattern_name})")
                if len(warning_artifacts) > 10:
                    print(f"      ... and {len(warning_artifacts) - 10} more warning artifacts")

    # Info
    print("\nℹ️  INFO:")
    for info in report.info:
        print(f"   {info}")


def get_artifact_cleaning_recommendations(report: ValidationReport) -> Dict[str, List[str]]:
    """
    Generate specific cleaning recommendations based on detected artifacts.

    Returns dict with categories and specific actions needed.
    """
    recommendations = {
        'placeholder_filling': [],
        'instruction_removal': [],
        'value_label_cleaning': [],
        'question_reformulation': [],
        'code_handling': [],
    }

    for artifact in report.artifacts:
        if artifact.artifact_type == 'placeholders':
            recommendations['placeholder_filling'].append(
                f"{artifact.location}: Replace '{artifact.matched_text}' - {artifact.suggestion}"
            )

        elif artifact.artifact_type == 'interviewer_instructions':
            recommendations['instruction_removal'].append(
                f"{artifact.location}: Remove '{artifact.matched_text}'"
            )

        elif artifact.artifact_type in ['binary_marking', 'scale_abbreviations']:
            recommendations['value_label_cleaning'].append(
                f"{artifact.location}: Convert '{artifact.matched_text}' to natural language"
            )

        elif artifact.artifact_type == 'skip_logic':
            recommendations['question_reformulation'].append(
                f"{artifact.location}: Remove routing logic '{artifact.matched_text}'"
            )

        elif artifact.artifact_type in ['response_codes', 'special_values']:
            recommendations['code_handling'].append(
                f"{artifact.location}: Handle special code '{artifact.matched_text}'"
            )

    # Deduplicate
    for key in recommendations:
        recommendations[key] = list(set(recommendations[key]))

    return recommendations

# %%
report = validate_metadata_structure(metadata)
print_validation_report(report, show_artifacts=True)
# Out:
# ======================================================================
# METADATA VALIDATION REPORT
# ======================================================================
#
# ✓ No critical structural issues found
#
# ✓ No warnings
#
# 🔍 ARTIFACT DETECTION SUMMARY:
#    Total artifacts found: 8229
#    - Critical: 2
#    - Warning: 4
#    - Info: 8223
#
#    By category:
#    - question_quality: 5183
#    - special_values: 1754
#    - missing_data_labels: 1275
#    - column_positions: 10
#    - interviewer_instructions: 4
#    - survey_series: 3
#
#    🚨 CRITICAL ARTIFACTS (require fixing):
#       [[political_affiliation] prtvthnl] values[16]
#          Pattern: variable_code_only
#          Matched: 'JA21'
#          Suggestion: Review and clean as appropriate
#       [[political_affiliation] prtclgnl] values[16]
#          Pattern: variable_code_only
#          Matched: 'JA21'
#          Suggestion: Review and clean as appropriate
#
#    ⚠️  SAMPLE WARNING ARTIFACTS:
#       [[demographics] isco08] values[4227]: ' interviewers' (interviewer_note)
#       [[demographics] isco08] values[4227]: ' interviewers' (interviewer_note)
#       [[demographics] isco08p] values[4227]: ' interviewers' (interviewer_note)
#       [[demographics] isco08p] values[4227]: ' interviewers' (interviewer_note)
#
# ℹ️  INFO:
#    Total sections: 12
#    Total variables: 551
#    Total value codes: 12960
#      - demographics: 276 variables
#      - media_information_sources: 4 variables
#      - other: 45 variables
#      - trust_in_social_groups: 26 variables
#      - politics: 29 variables
#      - governance: 23 variables
#      - civic_engagement: 19 variables
#      - trust_in_institutions: 18 variables
#      - political_affiliation: 50 variables
#      - economic_outlook: 7 variables
#      - climate_change: 23 variables
#      - covid: 31 variables

# %% [markdown]
# **For ESS: checked critical artefacts (JA21 is a real party, no fix needed), and warning artefacts are due to 'interviewer' being a valid isco job category, again no change needed.**

# %% [markdown]
# ---
# **Question Quality Review**
#
# Check the quality of question reformulation - a critical aspect of metadata creation. Code below samples random questions for examining them visually. Run a few times to see if you notice anything strange.

# %%
#@title question quality review
def review_question_quality(metadata: dict,
                            sample_size: int = 10,
                            seed: int = 42) -> None:
    """
    Display a sample of questions for manual review.

    Things to check:
    - Is the question natural and conversational?
    - Were survey artifacts removed ("looking at card", "interviewer records"...)?
    - Does the question make sense as a standalone question?
    """
    all_questions = []

    for section, variables in metadata.items():
        for var_code, var_data in variables.items():
            if 'question' in var_data:
                all_questions.append({
                    'section': section,
                    'code': var_code,
                    'description': var_data.get('description', ''),
                    'question': var_data['question'],
                    'n_options': len(var_data.get('values', {}))
                })

    # Random sample
    np.random.seed(seed)
    sample_idx = np.random.choice(len(all_questions), min(sample_size, len(all_questions)), replace=False)
    sample = [all_questions[i] for i in sample_idx]

    print("=" * 70)
    print("QUESTION QUALITY REVIEW (Random Sample)")
    print("=" * 70)
    print("\nCheck each question for:")
    print("  ✓ Natural, conversational tone")
    print("  ✓ Survey artifacts removed ('read card', 'interviewer records')")
    print("  ✓ Makes sense as standalone question")
    print("  ✓ Description accurately summarizes the question\n")

    for i, q in enumerate(sample, 1):
        print(f"\n--- [{i}/{len(sample)}] {q['code']} ({q['section']}) ---")
        print(f"Description: {q['description']}")
        print(f"Question: {q['question']}")
        print(f"Answer options: {q['n_options']}")


# Review questions
review_question_quality(metadata, sample_size=10, seed=None)
# Out:
# ======================================================================
# QUESTION QUALITY REVIEW (Random Sample)
# ======================================================================
#
# Check each question for:
#   ✓ Natural, conversational tone
#   ✓ Survey artifacts removed ('read card', 'interviewer records')
#   ✓ Makes sense as standalone question
#   ✓ Description accurately summarizes the question
#
#
# --- [1/10] fampref (other) ---
# Description: Familiarity with preference settings
# Question: How familiar are you with preference settings for computers and the internet?
# Answer options: 8
#
# --- [2/10] edlvmdfr (demographics) ---
# Description: Mother's education level
# Question: What is the highest level of education your mother completed in France?
# Answer options: 30
#
# --- [3/10] rlgatnd (demographics) ---
# Description: Religious service attendance
# Question: Aside from special occasions like weddings and funerals, how often do you attend religious services?
# Answer options: 10
#
# --- [4/10] rshpsmk (demographics) ---
# Description: Relationship with partner
# Question: What is your relationship to the husband, wife, or partner you are currently living with?
# Answer options: 8
#
# --- [5/10] stpldmc (trust_in_institutions) ---
# Description: Government policy adherence
# Question: How often do you think the government in this country follows through on its planned policies even if most people disagree?
# Answer options: 15
#
# --- [6/10] dscrntn (trust_in_social_groups) ---
# Description: Group discrimination (nationality)
# Question: Does your group face discrimination because of nationality?
# Answer options: 2
#
# --- [7/10] yrbrn8 (demographics) ---
# Description: Eighth household member birth year
# Question: What year was the eighth person in your household born?
# Answer options: 4
#
# --- [8/10] c19mcwrk (covid) ---
# Description: Work online communication change
# Question: Compared with before the coronavirus pandemic, how often do you now communicate online or by mobile with the people you work with?
# Answer options: 10
#
# --- [9/10] prtclame (political_affiliation) ---
# Description: Party closeness (Montenegro)
# Question: Which political party in Montenegro do you feel closest to?
# Answer options: 22
#
# --- [10/10] pbldmna (civic_engagement) ---
# Description: Public demonstration participation
# Question: In the last 12 months, have you taken part in a public demonstration in this country to try to improve things or to prevent things from going wrong?
# Answer options: 5

# %% [markdown]
# ---
# **Value Labels Review**
#
# Check that answer options are properly formatted and include special categories.

# %%
#@title value labels review
def review_value_labels(metadata: dict) -> None:
    """
    Review value labels for common issues:
    - Likert scales: Are they collapsed appropriately?
    - Missing values: Are special categories included?
    - Country-specific: Are options realistic for respondents?
    """

    # Common missing value patterns
    missing_patterns = ['missing', 'refused', "don't know", 'no answer', 'not asked', 'not applicable']

    likert_indicators = ['strongly', 'agree', 'disagree', 'satisfied', 'trust', 'important']

    issues = []
    string_vars = []  # Track open-text variables
    stats = {
        'total_vars': 0,
        'vars_with_missing': 0,
        'likely_likert': 0,
        'n_options_dist': []
    }

    for section, variables in metadata.items():
        for var_code, var_data in variables.items():
            if 'values' not in var_data:
                continue

            values = var_data['values']

            # Handle string/open-text variables
            if not isinstance(values, dict):
                string_vars.append((var_code, section, values))
                continue

            # Skip empty values dicts
            if len(values) == 0:
                continue

            stats['total_vars'] += 1
            labels_lower = [str(v).lower() for v in values.values()]

            stats['n_options_dist'].append(len(values))

            # Check for missing value categories
            has_missing = any(
                any(pattern in label for pattern in missing_patterns)
                for label in labels_lower
            )
            if has_missing:
                stats['vars_with_missing'] += 1

            # Check if likely Likert scale
            is_likert = any(
                any(indicator in label for indicator in likert_indicators)
                for label in labels_lower
            )
            if is_likert:
                stats['likely_likert'] += 1

            # Check for potential issues
            if len(set(values.values())) > 10 and is_likert:
                issues.append(
                    f"[{var_code}] Likert-like scale with {len(values)} options - may need collapsing"
                )

            # Check for numeric-only labels
            numeric_labels = [v for v in values.values() if str(v).strip().isdigit()]
            if numeric_labels and len(numeric_labels) > 2:
                issues.append(
                    f"[{var_code}] Has numeric-only labels: {numeric_labels[:3]}... - may need verbal anchors"
                )

    print("=" * 60)
    print("VALUE LABELS ANALYSIS")
    print("=" * 60)

    # Handle case where no categorical variables found
    if stats['total_vars'] == 0:
        print("\n⚠️  No categorical variables with value mappings found")
    else:
        print(f"\nTotal categorical variables: {stats['total_vars']}")
        print(f"Variables with missing value categories: {stats['vars_with_missing']} ({100*stats['vars_with_missing']/stats['total_vars']:.1f}%)")
        print(f"Likely Likert scales: {stats['likely_likert']}")
        print(f"\nOptions per variable distribution:")
        print(f"  Min: {min(stats['n_options_dist'])}, Max: {max(stats['n_options_dist'])}, Median: {np.median(stats['n_options_dist']):.0f}")

    # Report string/open-text variables
    if string_vars:
        print(f"\nℹ️  Open-text/verbatim variables ({len(string_vars)}):")
        for var_code, section, val_type in string_vars[:10]:
            print(f"   • {var_code} ({section}): {val_type}")
        if len(string_vars) > 10:
            print(f"   ... and {len(string_vars) - 10} more")

    if issues:
        print("\n⚠️  POTENTIAL ISSUES:")
        for issue in issues[:50]:  # Limit output
            print(f"   • {issue}")
        if len(issues) > 50:
            print(f"   ... and {len(issues) - 50} more")
    else:
        print("\n✓ No obvious issues with value labels")


review_value_labels(metadata)
# Out:
# ============================================================
# VALUE LABELS ANALYSIS
# ============================================================
#
# Total categorical variables: 551
# Variables with missing value categories: 508 (92.2%)
# Likely Likert scales: 57
#
# Options per variable distribution:
#   Min: 1, Max: 2304, Median: 11
#
# ⚠️  POTENTIAL ISSUES:
#    • [inprdsc] Has numeric-only labels: ['1', '2', '3']... - may need verbal anchors

# %% [markdown]
# ---
#
# Inspect specific variables in detail.

# %%
#@title **Detailed Variable Inspection**
def inspect_variable(metadata: dict, var_code: str) -> None:
    """Display full details for a specific variable."""

    for section, variables in metadata.items():
        if var_code in variables:
            var_data = variables[var_code]
            print(f"\n{'='*60}")
            print(f"VARIABLE: {var_code}")
            print(f"{'='*60}")
            print(f"Section: {section}")
            print(f"Description: {var_data.get('description', 'N/A')}")
            print(f"\nQuestion:")
            print(f"  {var_data.get('question', 'N/A')}")
            print(f"\nAnswer Options ({len(var_data.get('values', {}))} total):")
            for code, label in var_data.get('values', {}).items():
                print(f"  [{code}] {label}")
            if 'notes' in var_data:
                print(f"\nNotes: {var_data['notes']}")
            return

    print(f"Variable '{var_code}' not found in metadata")


# Example: inspect a specific variable
# Replace with a variable code from your metadata
# inspect_variable(metadata, 'Q35A')

# %%
# List all variable codes for reference
print("All variable codes in metadata:\n")
for section, variables in metadata.items():
    print(f"[{section}]")
    print(f"  {', '.join(variables.keys())}\n")
# Out:
# All variable codes in metadata:
#
# [demographics]
#   cntry, imdfetn, health, hlthhmp, rlgblg, rlgdnm, rlgdnach, rlgdnafi, rlgdnagr, rlgdnhu, rlgdnais, rlgdnie, rlgdnlt, rlgdme, rlgdnanl, rlgdnmk, rlgdnno, rlgdnbsk, rlgdngb, rlgblge, rlgdnme, rlgdeach, rlgdeafi, rlgdeagr, rlgdehu, rlgdeais, rlgdeie, rlgdelt, rlgdeme, rlgdeanl, rlgdemk, rlgdeno, rlgdebsk, rlgdegb, rlgdgr, rlgatnd, dscretn, ctzcntr, brncntr, cntbrthd, livecnta, lnghom1, lnghom2, feethngr, facntr, fbrncntc, mocntr, mbrncntc, hhmmb, gndr, gndr2, gndr3, gndr4, gndr5, gndr6, gndr7, gndr8, gndr9, gndr10, gndr11, gndr12, gndr13, yrbrn, agea, yrbrn2, yrbrn3, yrbrn4, yrbrn5, yrbrn6, yrbrn7, yrbrn8, yrbrn9, yrbrn10, yrbrn11, yrbrn12, yrbrn13, rshipa2, rshipa3, rshipa4, rshipa5, rshipa6, rshipa7, rshipa8, rshipa9, rshipa10, rshipa11, rshipa12, rshipa13, rshpsts, rshpsmk, rshpsgb, lvgptnea, dvrcdeva, marsts, marstmk, marstgb, maritalb, chldhhe, domicil, edulvlb, eisced, edlvebe, edlvebg, edlvdch, edlvehr, edlvdcz, edlvdee, edlvdfi, edlvdfr, edlvegr, edlvdahu, edlvdis, edlvdie, edlveit, edlvdlt, edlvdme, edlvenl, edlvdmk, edlveno, edlvdpt, edlvesi, edlvdsk, educgb1, edubgb2, edagegb, eduyrs, pdwrk, uempla, uempli, dsbld, rtrd, hswrk, mainact, mnactic, crpdwk, pdjobev, pdjobyr, emplrel, emplno, wrkctra, estsz, jbspv, njbspv, wkhct, wkhtot, nacer2, tporgwk, isco08, wrkac6m, uemp12m, uemp5yr, mbtru, hincsrca, hinctnta, edulvlpb, eiscedp, edlvpebe, edlvpebg, edlvpdch, edlvpehr, edlvpdcz, edlvpdee, edlvpdfi, edlvpdfr, edlvpegr, edlvpdahu, edlvpdis, edlvpdie, edlvpeit, edlvpdlt, edlvpdme, edlvpenl, edlvpdmk, edlvpeno, edlvpdpt, edlvpesi, edlvpdsk, edupcgb1, edupbgb2, edagepgb, pdwrkp, edctnp, uemplap, uemplip, dsbldp, rtrdp, hswrkp, mnactp, crpdwkp, isco08p, emprelp, wkhtotp, edulvlfb, eiscedf, edlvfebe, edlvfebg, edlvfdch, edlvfehr, edlvfdcz, edlvfdee, edlvfdfi, edlvfdfr, edlvfegr, edlvfdahu, edlvfdis, edlvfdie, edlvfeit, edlvfdlt, edlvfdme, edlvfenl, edlvfdmk, edlvfeno, edlvfdpt, edlvfesi, edlvfdsk, edufcgb1, edufbgb2, edagefgb, emprf14, occf14b, edulvlmb, eiscedm, edlvmebe, edlvmebg, edlvmdch, edlvmehr, edlvmdcz, edlvmdee, edlvmdfi, edlvmdfr, edlvmegr, edlvmdahu, edlvmdis, edlvmdie, edlvmeit, edlvmdlt, edlvmdme, edlvmenl, edlvmdmk, edlvmeno, edlvmdpt, edlvmesi, edlvmdsk, edumcgb1, edumbgb2, edagemgb, emprm14, occm14b, anctry1, anctry2, region, acchome, accwrk, chldo12, gndro12a, gndro12b, ageo12, hhlio12, closeo12, ttmino12, speako12, scrno12, phoneo12, como12, livpnt, pntmofa, agepnt, hhlipnt, ttminpnt, speakpnt, scrnpnt, phonepnt, wrkhome, colprop, impdiff, imptrad
#
# [media_information_sources]
#   nwspol, netusoft, accmove, mcmsinf
#
# [other]
#   netustm, stflife, freehms, happy, crmvct, atchctr, atcherp, pray, dscroth, edctn, accoth, accnone, fampref, famadvs, fampdf, mcclose, mcinter, mcpriv, closepnt, compnt, trdawrk, jbprtfp, pfmfdjba, wrklong, wrkresp, mansupp, manwrkpl, manspeak, manscrn, manphone, mancom, colspeak, colscrn, colphone, colcom, mcwrkhom, ipcrtiv, ipfrule, ipmodst, ipgdtim, impfree, ipsuces, ipadvnt, impfun, admc19
#
# [trust_in_social_groups]
#   ppltrst, pplfair, pplhlp, trstsci, hmsfmlsh, imwbcnt, inprdsc, aesfdrk, dscrgrp, dscrrce, dscrntn, dscrrlg, dscrlng, dscrage, dscrgnd, dscrsex, dscrdsb, manhlp, teamfeel, colhlp, ipeqopt, ipshabt, impsafe, ipbhprp, iprspot, iplylfr
#
# [politics]
#   polintr, psppipla, cptppola, hmsacld, euftf, lrnobed, loylead, imsmetn, impcntr, vteurmmb, fairelc, dfprtal, votedir, gptpelc, viepol, wpestop, keydec, dfprtalc, votedirc, wpestopc, chpldm, stpldmi, impdema, impdemb, impdemc, impdemd, impdeme, accalaw, secgrdec
#
# [governance]
#   psppsgva, stfdem, stfedu, stfhlth, gincdif, medcrgv, rghmgpr, cttresa, gvctzpv, grdfinc, gptpelcc, grdfincc, keydecc, chpldmi, chpldmc, implvdm, wkdcorga, iorgact, dcsfwrka, ipstrgv, govpriph, govmonpb, gvbalc19
#
# [civic_engagement]
#   actrolga, vote, contplt, donprty, badge, sgnptit, pbldmna, bctprd, pstplonl, volunfp, imueclt, sclmeet, sclact, cmsrv, cmsrvp, atncrse, mccoord, ipudrst, iphlppl
#
# [trust_in_institutions]
#   trstprl, trstlgl, trstplc, trstplt, trstprt, trstep, trstun, stfgov, fairelcc, medcrgvc, rghmgprc, cttresac, gvctzpvc, viepolc, stpldmc, scidecpb, gvhanc19, gvimpc19
#
# [political_affiliation]
#   prtvtebe, prtvtebg, prtvthch, prtvtbhr, prtvtecz, prtvthee, prtvtefi, prtvtefr, prtvtdgr, prtvtghu, prtvtdis, prtvtdie, prtvtdit, prtvclt1, prtvclt2, prtvclt3, prtvtame, prtvthnl, prtvtmk, prtvtbno, prtvtdpt, prtvtfsi, prtvtesk, prtvtdgb, clsprty, prtclebe, prtclebg, prtclhch, prtclbhr, prtclecz, prtclhee, prtclffi, prtclffr, prtcldgr, prtclhhu, prtcldis, prtclfie, prtcleit, prtclclt, prtclame, prtclgnl, prtclmk, prtclbno, prtclfpt, prtclfsi, prtclesk, prtcldgb, prtdgcl, lrscale, vteubcmb
#
# [economic_outlook]
#   stfeco, imbgeco, uemp3m, hincfel, stfmjob, wrkextra, imprich
#
# [climate_change]
#   ccnthum, ccrdprs, wrclmch, admrclc, testic34, testic35, testic36, testic37, testic38, testic39, testic40, testic41, testic42, impenv, testii1, testii2, testii3, testii4, testii5, testii6, testii7, testii8, testii9
#
# [covid]
#   c19spo12, c19mco12, c19sppnt, c19mcpnt, c19whome, c19wplch, c19whacc, c19spwrk, c19mcwrk, panpriph, panmonpb, panfolru, panclobo, panresmo, gvjobc19, gveldc19, gvfamc19, hscopc19, gvconc19, respc19, reshhc19, hapljc19, hapirc19, hapwrc19, hapfuc19, hapfoc19, hapnoc19, hapnwc19, icvacc19, getavc19, getnvc19

# %%
inspect_variable(metadata, 'wrclmch')
# Out:
# ============================================================
# VARIABLE: wrclmch
# ============================================================
# Section: climate_change
# Description: Worry about climate change
#
# Question:
#   How worried are you about climate change?
#
# Answer Options (9 total):
#   [1] Not at all worried
#   [2] Not very worried
#   [3] Somewhat worried
#   [4] Very worried
#   [5] Extremely worried
#   [6] Not applicable
#   [7] Refusal
#   [8] Don't know
#   [9] No answer

# %% [markdown]
# ---
# ## **3. Profile Generator Overview**
#
# ### **Purpose**
#
# The `RespondentProfileGenerator` converts tabular survey data into natural language "interview" representations suitable for LLM inference. Given a respondent's row in a survey dataset and structured metadata about the questions, it produces text-based profiles that describe what we know about a person, paired with a target question we want the model to predict.
#
# This enables our core research question: can LLMs predict individual survey responses given partial information about respondents? The generator handles the critical task of transforming structured survey data into the text format LLMs expect, while implementing safeguards against information leakage and ensuring experimental reproducibility.
#
# ### **Core Functionality**
#
# The generator provides several key capabilities:
#
# - **Stratified random sampling**: Selects features across thematic sections (demographics, political attitudes, etc.) rather than clustering features from one domain
# - **Seedable reproducibility**: All sampling is deterministic given a seed, enabling exact replication of experiments
# - **Profile expansion**: Generates nested profiles where smaller profiles are strict subsets of larger ones—essential for information richness experiments where we vary how much context the model receives
# - **Target question handling**: Automatically excludes target questions from the feature pool and handles country-specific answer options (e.g., showing only German parties to German respondents)
# - **Semantic similarity filtering**: Uses sentence embeddings to exclude features too similar to the target, preventing information leakage (e.g., excluding "party identification" when predicting "party vote")
# - **Missing value handling**: Filters out survey artifacts like "Not asked in this country" or "Refused" from both feature values and answer options
# - **Flexible output formatting**: Produces prompts in multiple formats (Q&A, interview, bullet points, etc.) to test robustness against surface-level variations
#
# ### **What to Test For**
#
# When validating metadata with the generator, watch for these common issues:
#
# **Data-metadata misalignment**: Variable codes in metadata don't match column names in the survey data, causing `KeyError` or silent failures where respondents have no valid features. The generator should warn about this, but verify the overlap percentage is high.
#
# **Missing value contamination**: If missing value patterns aren't configured correctly, profiles may include nonsensical features like "What is your religion? → Not asked in this country" or target options may include "Refused" as a valid answer choice.
#
# **Semantic filtering edge cases**: The similarity model may exclude too many features (overly aggressive) or miss obviously related questions (too permissive). Check the exclusion lists make sense—if predicting party vote, party identification should be excluded; general political interest probably shouldn't be.
#
# **Country-specific option failures**: For questions like party preference, respondents should only see parties from their country. If you see "Democrats (USA)" as an option for a German respondent, the country column mapping or country-specific target configuration is wrong.
#
# **Profile expansion violations**: When generating profiles of increasing size with the same seed, smaller profiles must be strict subsets of larger ones. If a feature appears in the 5-feature profile but not the 10-feature profile, the expansion logic is broken—this would confound information richness experiments.
#
# **Empty or sparse profiles**: Some respondents may have too many missing values to generate valid profiles, or some targets may have all features excluded by similarity filtering. The generator should handle these gracefully, but check that you can generate profiles for a reasonable proportion of respondents.
#
# **Value code mismatches**: If a respondent's answer in the data (e.g., `"7"`) doesn't appear in the metadata's value mapping, the generator may fail or produce raw codes instead of human-readable labels. Spot-check that generated profiles show text labels, not numeric codes.
#
# ### **Prerequisites**:
# You need actual survey data (CSV) that matches the metadata.

# %%
# Load survey data (skip if not available)
try:
    survey_df = pd.read_csv("../../../../../data/ess/ESS10.csv", low_memory=False)  # ESS

    # Generate unique respondent ID (if needed for particular dataset, as some use the same ID numbers across countries)
    survey_df["cntry_idno"] = (
        survey_df["cntry"].astype("string") + "_" + survey_df["idno"].astype("string")
    )

    print(f"✓ Loaded survey data: {survey_df.shape[0]} respondents, {survey_df.shape[1]} columns")

    n_unique = survey_df["cntry_idno"].nunique(dropna=False)
    if n_unique != len(survey_df):
        warnings.warn(
            f'cntry_idno is not unique: {n_unique} unique IDs for {survey_df.shape[0]} rows.',
            category=UserWarning
        )

    print(f"  Columns: {list(survey_df.columns)[:10]}...")

except FileNotFoundError:
    print("⚠️  Survey data file not found. Using mock data for demo.")
    survey_df = None
# Out:
# ✓ Loaded survey data: 37611 respondents, 619 columns
#   Columns: ['name', 'essround', 'edition', 'proddate', 'idno', 'cntry', 'dweight', 'pspwght', 'pweight', 'anweight']...

# %%
# ============================================================
# CONFIGURE GENERATOR PARAMETERS
# ============================================================

RESPONDENT_ID_COL = 'cntry_idno'  # Column with respondent IDs
COUNTRY_COL = 'cntry'  # Set to column name if your data has country info (e.g., 'B_COUNTRY')

# Missing value configuration
MISSING_VALUE_LABELS = ['Refusal', "Don't know", 'No answer', '', 'Not applicable']  # Exact matches
MISSING_VALUE_PATTERNS = ['not asked', "don't know", 'missing', 'refused']  # Substring matches

# Semantic similarity (optional - requires sentence-transformers)
USE_SEMANTIC_FILTERING = True  # Set to True if sentence-transformers is installed
SIMILARITY_MODEL = 'all-MiniLM-L6-v2'  # Fast and effective, but feel free to experiment with other models
SIMILARITY_THRESHOLD = 0.8  # Features with similarity >= this are excluded

# %%
# Initialize the generator
try:
    generator = RespondentProfileGenerator(
        survey_data=survey_df,
        metadata=metadata,
        respondent_id_col=RESPONDENT_ID_COL,
        country_col=COUNTRY_COL,
        missing_value_labels=MISSING_VALUE_LABELS,
        missing_value_patterns=MISSING_VALUE_PATTERNS,
        similarity_model=SIMILARITY_MODEL if USE_SEMANTIC_FILTERING else None,
        similarity_threshold=SIMILARITY_THRESHOLD
    )
    print("✓ Generator initialized successfully!")
    print(f"  Available sections: {list(generator._section_to_features.keys())}")
    print(f"  Total features: {len(generator._all_features)}")
except Exception as e:
    print(f"❌ Error initializing generator: {e}")
    raise
# Out:
# Missing value exclusion configured:
#   Exact labels: {'', 'Not applicable', "Don't know", 'No answer', 'Refusal'}
#   Patterns (case-insensitive): ['not asked', "don't know", 'missing', 'refused']
# Semantic similarity filtering enabled:
#   Model: all-MiniLM-L6-v2
#   Threshold: 0.8
# ✓ Generator initialized successfully!
#   Available sections: ['demographics', 'media_information_sources', 'other', 'trust_in_social_groups', 'politics', 'governance', 'civic_engagement', 'trust_in_institutions', 'political_affiliation', 'economic_outlook', 'climate_change', 'covid']
#   Total features: 551

# %% [markdown]
# ---
# **Generate Sample Profiles**
#
# Test profile generation with different settings.

# %%
# ============================================================
# CONFIGURE TARGET QUESTIONS
# ============================================================

# Select some variables as target questions (what we want to predict)
# Replace with actual variable codes from your metadata
TARGET_CODES = ["gndr", "c19mcpnt", "mnactp", "trstplt", "eisced", "health", "eiscedm", "hincsrca", 
                "hincfel", "uempla", "happy", "wrkresp", "polintr", "loylead", "impdema", "psppsgva", 
                "chpldmc", "govpriph", "vote", "volunfp", "ipudrst", "fairelcc", "imprich", "stfeco", 
                "impenv"]  # <-- Add target variable codes here, e.g., ['Q35A', 'Q35B']

# For country-specific targets (like party vote), specify them here
COUNTRY_SPECIFIC_TARGETS = []  # e.g., ['PARTY_VOTE'] if applicable

if not TARGET_CODES:
    # Auto-select first few variables as targets for demo
    all_vars = []
    for section, variables in metadata.items():
        all_vars.extend(list(variables.keys())[:2])
    TARGET_CODES = all_vars[:3]
    print(f"Auto-selected target codes for demo: {TARGET_CODES}")

# %%
# Set target questions
generator.set_target_questions(
    target_codes=TARGET_CODES,
    country_specific_targets=COUNTRY_SPECIFIC_TARGETS if COUNTRY_SPECIFIC_TARGETS else None
)
print(f"\n✓ Target questions set: {TARGET_CODES}")
# Out:
#   Computing semantic similarity (model: all-MiniLM-L6-v2)...
#     c19mcpnt: excluding 2 similar features
#       - c19mco12 (sim=0.927): "Compared with before the coronavirus pandemic, wou..."
#       - c19mcwrk (sim=0.869): "Compared with before the coronavirus pandemic, how..."
#     trstplt: excluding 1 similar features
#       - trstprt (sim=0.813): "How much do you personally trust political parties..."
#     eisced: excluding 40 similar features
#       - edulvlb (sim=1.000): "What is the highest level of education you have co..."
#       - edlvdme (sim=1.000): "What is the highest level of education you have co..."
#       - edlveit (sim=1.000): "What is the highest level of education you have co..."
#       ... and 37 more
#     eiscedm: excluding 42 similar features
#       - edlvmdis (sim=1.000): "What is the highest level of education your mother..."
#       - edlvmdlt (sim=1.000): "What is the highest level of education your mother..."
#       - edlvmesi (sim=1.000): "What is the highest level of education your mother..."
#       ... and 39 more
#     uempla: excluding 1 similar features
#       - uempli (sim=0.961): "In the past 7 days, were you unemployed, wanted a ..."
#     impdema: excluding 4 similar features
#       - impdemc (sim=1.000): "What do you think is the most important for democr..."
#       - impdemd (sim=1.000): "What do you think is the most important for democr..."
#       - impdemb (sim=1.000): "What do you think is the most important for democr..."
#       ... and 1 more
#     psppsgva: excluding 1 similar features
#       - psppipla (sim=0.803): "How much does the political system in this country..."
#     chpldmc: excluding 1 similar features
#       - stpldmc (sim=0.886): "How often do you think the government in this coun..."
#     fairelcc: excluding 1 similar features
#       - fairelc (sim=0.866): "How important is it for democracy overall that nat..."
# Set 25 target questions. These are now excluded from the feature pool.
#   Filtered 76 missing/artifact options (from 243 to 167 total options)
#
# ✓ Target questions set: ['gndr', 'c19mcpnt', 'mnactp', 'trstplt', 'eisced', 'health', 'eiscedm', 'hincsrca', 'hincfel', 'uempla', 'happy', 'wrkresp', 'polintr', 'loylead', 'impdema', 'psppsgva', 'chpldmc', 'govpriph', 'vote', 'volunfp', 'ipudrst', 'fairelcc', 'imprich', 'stfeco', 'impenv']

# %%
# Check which labels are removed as missing options (make sure the removal approach is not too aggressive)
filtered_out_by_code = {}

for code, tq in generator._target_questions.items():
    values_map = tq.values_map  # dict: raw_value -> label

    removed = {}
    kept = {}

    for raw_value, label in values_map.items():
        if generator._is_missing_value_label(label):
            removed[raw_value] = label
        else:
            kept[raw_value] = label

    if removed:
        filtered_out_by_code[code] = {
            "removed": removed,
            "removed_n": len(removed),
            "kept_n": len(kept),
            "total_n": len(values_map),
        }

# Summary sorted by how many were removed
for code, info in sorted(filtered_out_by_code.items(), key=lambda x: x[1]["removed_n"], reverse=True):
    print(f"{code}: removed {info['removed_n']} of {info['total_n']} (kept {info['kept_n']})")

# Inspect one target in detail
example_code = 'govpriph'
print("\nDetailed removed options for:", example_code)
for k, v in sorted(filtered_out_by_code[example_code]["removed"].items(), key=lambda x: str(x[0])):
    print(f"  {k!r}: {v}")
# Out:
# c19mcpnt: removed 4 of 9 (kept 5)
# mnactp: removed 4 of 13 (kept 9)
# wrkresp: removed 4 of 10 (kept 6)
# impdema: removed 4 of 9 (kept 5)
# chpldmc: removed 4 of 15 (kept 11)
# govpriph: removed 4 of 15 (kept 11)
# trstplt: removed 3 of 14 (kept 11)
# eisced: removed 3 of 12 (kept 9)
# health: removed 3 of 8 (kept 5)
# eiscedm: removed 3 of 12 (kept 9)
# hincsrca: removed 3 of 11 (kept 8)
# hincfel: removed 3 of 7 (kept 4)
# happy: removed 3 of 14 (kept 11)
# polintr: removed 3 of 7 (kept 4)
# loylead: removed 3 of 8 (kept 5)
# psppsgva: removed 3 of 8 (kept 5)
# vote: removed 3 of 6 (kept 3)
# volunfp: removed 3 of 5 (kept 2)
# ipudrst: removed 3 of 9 (kept 6)
# fairelcc: removed 3 of 14 (kept 11)
# imprich: removed 3 of 9 (kept 6)
# stfeco: removed 3 of 14 (kept 11)
# impenv: removed 3 of 9 (kept 6)
# gndr: removed 1 of 3 (kept 2)
#
# Detailed removed options for: govpriph
#   '66': Not applicable
#   '77': Refusal
#   '88': Don't know
#   '99': No answer

# %%
# import inspect
# print(inspect.getsource(generator.set_target_questions))
# Out:
#     def set_target_questions(
#         self,
#         target_codes: list[str],
#         country_specific_targets: Optional[list[str]] = None,
#         auto_detect_country_specific: bool = True,
#         country_specific_threshold: float = 0.5
#     ):
#         """
#         Set the list of target questions for prediction.
#
#         These questions are automatically excluded from the feature pool
#         and can be used to generate prediction instances.
#
#         Missing/artifact values (as configured in __init__) are automatically
#         filtered from the answer options.
#
#         Parameters
#         ----------
#         target_codes : list[str]
#             List of question codes that will serve as prediction targets
#         country_specific_targets : list[str], optional
#             Explicit list of targets that should have country-specific options.
#             If None and auto_detect_country_specific=True, will be detected automatically.
#             If provided, auto-detection is skipped for these codes.
#         auto_detect_country_specific : bool, default True
#             If True, automatically detect which targets need country-specific options
#             based on response distribution variance across countries.
#         country_specific_threshold : float, default 0.5
#             Threshold for auto-detection. Lower = more conservative.
#             A target is flagged if (avg_options_per_country / global_options) < threshold.
#         """
#         self._target_questions = {}
#         unknown_codes = []
#
#         for code in target_codes:
#             found = False
#             for section, questions in self.metadata.items():
#                 if code in questions:
#                     q_info = questions[code]
#                     values_map = q_info.get('values', {})
#
#                     # Filter out missing/artifact values from options
#                     valid_options = self._filter_valid_options(values_map)
#
#                     self._target_questions[code] = TargetQuestion(
#                         code=code,
#                         question=q_info.get('question', q_info.get('description', code)),
#                         description=q_info.get('description', ''),
#                         section=section,
#                         options=valid_options,  # Global options (may be overridden per-country)
#                         values_map=values_map
#                     )
#                     found = True
#                     break
#
#             if not found:
#                 unknown_codes.append(code)
#
#         if unknown_codes:
#             import warnings
#             warnings.warn(f"Target question codes not found in metadata: {unknown_codes}")
#
#         # Determine country-specific targets
#         if country_specific_targets is not None:
#             # User provided explicit list
#             self._country_specific_targets = set(country_specific_targets)
#         elif auto_detect_country_specific and self.country_col:
#             # Auto-detect
#             self._country_specific_targets = self._detect_country_specific_targets(
#                 target_codes, threshold=country_specific_threshold
#             )
#         else:
#             self._country_specific_targets = set()
#
#         # Validate country_specific_targets
#         invalid_country_specific = self._country_specific_targets - set(target_codes)
#         if invalid_country_specific:
#             import warnings
#             warnings.warn(
#                 f"country_specific_targets contains codes not in target_codes: "
#                 f"{invalid_country_specific}"
#             )
#
#         # Build country-specific options lookup if needed
#         if self._country_specific_targets and self.country_col:
#             self._build_country_specific_options()
#         elif self._country_specific_targets and not self.country_col:
#             import warnings
#             warnings.warn(
#                 "country_specific_targets specified but no country_col configured. "
#                 "Country-specific options will not be used."
#             )
#             self._country_specific_targets = set()
#
#         # Automatically add target questions to exclusions
#         self.add_exclusions(target_codes)
#
#         # Compute semantic similarity exclusions if model is configured
#         if self.similarity_model_name:
#             self._target_similar_features = self._compute_similarity_exclusions(target_codes)
#         else:
#             self._target_similar_features = {code: set() for code in target_codes}
#
#         # Report
#         total_original = sum(
#             len(self.metadata[self._feature_to_section[code]][code].get('values', {}))
#             for code in self._target_questions
#         )
#         total_filtered = sum(len(t.options) for t in self._target_questions.values())
#
#         print(f"Set {len(self._target_questions)} target questions. "
#               f"These are now excluded from the feature pool.")
#         if total_original != total_filtered:
#             print(f"  Filtered {total_original - total_filtered} missing/artifact options "
#                   f"(from {total_original} to {total_filtered} total options)")
#         if self._country_specific_targets:
#             print(f"  Country-specific options: {list(self._country_specific_targets)} (auto-detected)"
#                   if auto_detect_country_specific and country_specific_targets is None
#                   else f"  Country-specific options: {list(self._country_specific_targets)}")

# %%
# Generate a sample profile
sample_respondent_id = survey_df[RESPONDENT_ID_COL].iloc[0]
sample_target = TARGET_CODES[0]

print(f"Generating profile for respondent {sample_respondent_id}, target: {sample_target}")
print("=" * 70)

# Generate with different richness levels
for n_sections, m_features in [(1, 2), (2, 3), (3, 4)]:
    print(f"\n--- Profile: {n_sections} sections × {m_features} features/section ---")

    try:
        instance = generator.generate_prediction_instance(
            respondent_id=sample_respondent_id,
            target_code=sample_target,
            n_sections=n_sections,
            m_features_per_section=m_features,
            seed=42  # Reproducible
        )

        print(f"\nProfile ({len(instance.features)} features):")
        for q, a in instance.features.items():
            print(f"  • {q[:50]}... → {a}")

        print(f"\nTarget question: {instance.target_question[:75]}...")
        print(f"Answer options: {instance.options}")
        print(f"True answer: {instance.answer}")

    except Exception as e:
        print(f"Error: {e}")
# Out:
# Generating profile for respondent BE_10038, target: gndr
# ======================================================================
#
# --- Profile: 1 sections × 2 features/section ---
#
# Profile (2 features):
#   • Do you feel closer to any one political party than... → No
#   • Where would you place yourself on the political sp... → Left
#
# Target question: What is your gender?...
# Answer options: ['Male', 'Female']
# True answer: Female
#
# --- Profile: 2 sections × 3 features/section ---
#
# Profile (5 features):
#   • Do you feel closer to any one political party than... → No
#   • Where would you place yourself on the political sp... → Left
#   • If many people used less energy, how likely is it ... → Likely
#   • How likely do you think it is that many people wil... → Not very likely
#   • How likely is it that enough governments will take... → Neither likely nor unlikely
#
# Target question: What is your gender?...
# Answer options: ['Male', 'Female']
# True answer: Female
#
# --- Profile: 3 sections × 4 features/section ---
#
# Profile (10 features):
#   • How well does this statement describe you: "It's i... → Like me
#   • Is your group discriminated against because of dis... → No
#   • Would you feel ashamed if a close family member we... → Disagree
#   • How safe do you feel walking alone in your local a... → Safe
#   • Do you feel closer to any one political party than... → No
#   • Where would you place yourself on the political sp... → Left
#   • How likely do you think it is that if many people ... → Not likely
#   • How likely is it that enough governments will take... → Neither likely nor unlikely
#   • How likely do you think it is that many people wil... → Not likely
#   • How much personal responsibility do you feel to ta... → Somewhat
#
# Target question: What is your gender?...
# Answer options: ['Male', 'Female']
# True answer: Female
# C:\Users\matth\Brown Dropbox\Matthias Roesti\Oxford_LLMs\fork\synthetic_sampling\src\synthetic_sampling\profiles\generator.py:743: UserWarning: Respondent BE_10038: some sections had insufficient valid features after filtering missing values: ['political_affiliation: got 2/3']
#   warnings.warn(
# C:\Users\matth\Brown Dropbox\Matthias Roesti\Oxford_LLMs\fork\synthetic_sampling\src\synthetic_sampling\profiles\generator.py:743: UserWarning: Respondent BE_10038: some sections had insufficient valid features after filtering missing values: ['political_affiliation: got 2/4']
#   warnings.warn(

# %% [markdown]
# ---
# **Information Leakage Analysis**
#
# **Critical for experiment validity**: When predicting a target question, we must exclude features that would trivially reveal the answer.
#
# This section helps you:
# 1. See which features are excluded for each target (via semantic similarity)
# 2. Verify exclusions make sense
# 3. Identify potential leakage the filter might miss

# %%
generator.similarity_threshold
# Out:
# 0.8

# %%
#@title analyze information leakage
def analyze_information_leakage(
    generator: RespondentProfileGenerator,
    target_codes: list,
    top_k: int = 10
) -> None:
    """
    Analyze potential information leakage for each target question.

    Shows:
    - Features excluded by semantic similarity filtering
    - Top-k most similar features (even if below threshold)
    - Potential leakage risks to review manually
    """

    # Check if semantic filtering is enabled
    if not hasattr(generator, 'similarity_model_name') or generator.similarity_model_name is None:
        print("⚠️  Semantic similarity filtering is DISABLED")
        print("   To enable, reinitialize generator with:")
        print("   similarity_model='all-MiniLM-L6-v2'")
        print("\n   Without semantic filtering, only exact target exclusion is applied.")
        return

    print("="*70)
    print("INFORMATION LEAKAGE ANALYSIS")
    print(f"Similarity threshold: {generator.similarity_threshold}")
    print("="*70)

    for target_code in target_codes:
        print(f"\n--- Target: {target_code} ---")

        # Get target question text
        target_text = None
        for section, variables in generator.metadata.items():
            if target_code in variables:
                target_text = variables[target_code].get('question', '')
                break

        if not target_text:
            print(f"  Target not found in metadata")
            continue

        print(f"  Question: {target_text[:80]}...")

        # Get excluded features for this target (correct attribute name)
        if hasattr(generator, '_target_similar_features') and target_code in generator._target_similar_features:
            excluded = generator._target_similar_features[target_code]
            if excluded:
                print(f"\n  ❌ EXCLUDED features ({len(excluded)}):")

                # Get similarity scores using the generator's method
                similar_features = generator.get_similar_features(target_code)

                # Sort excluded features by similarity score
                excluded_with_scores = [
                    (feat, similar_features.get(feat, 0.0))
                    for feat in excluded
                ]
                excluded_with_scores.sort(key=lambda x: -x[1])

                for feat_code, sim_score in excluded_with_scores[:top_k]:
                    # Get feature question text
                    feat_text = ""
                    for section, variables in generator.metadata.items():
                        if feat_code in variables:
                            feat_text = variables[feat_code].get('question', '')[:80]
                            break
                    print(f"     • {feat_code} (sim={sim_score:.3f}): {feat_text}...")

                if len(excluded_with_scores) > top_k:
                    print(f"     ... and {len(excluded_with_scores) - top_k} more")
            else:
                print(f"\n  ✓ No features excluded by similarity filtering")
        else:
            print(f"\n  ✓ No features excluded by similarity filtering")

        # Show top similar features (even if not excluded)
        print(f"\n  ℹ️  Top {top_k} most similar features (for review):")
        try:
            similar_features = generator.get_similar_features(target_code)
            sorted_similar = sorted(similar_features.items(), key=lambda x: -x[1])[:top_k]

            for feat_code, sim_score in sorted_similar:
                status = "❌" if sim_score >= generator.similarity_threshold else "✓"
                feat_text = generator._code_to_question_text.get(feat_code, feat_code)[:80]
                print(f"     {status} {feat_code} (sim={sim_score:.3f}): {feat_text}...")
        except Exception as e:
            print(f"     Could not compute similarities: {e}")

# %%
# Run information leakage analysis
analyze_information_leakage(generator, TARGET_CODES)
# Out:
# ======================================================================
# INFORMATION LEAKAGE ANALYSIS
# Similarity threshold: 0.8
# ======================================================================
#
# --- Target: gndr ---
#   Question: What is your gender?...
#
#   ✓ No features excluded by similarity filtering
#
#   ℹ️  Top 10 most similar features (for review):
#      ✓ gndr8 (sim=0.620): What is the gender of the eighth person in your household?...
#      ✓ gndr4 (sim=0.614): What is the gender of the fourth person in your household?...
#      ✓ gndr3 (sim=0.613): What is the gender of the third person in your household?...
#      ✓ gndr5 (sim=0.612): What is the gender of the fifth person in your household?...
#      ✓ gndr6 (sim=0.608): What is the gender of the sixth person in your household?...
#      ✓ gndr2 (sim=0.606): What is the gender of the second person in your household?...
#      ✓ gndr7 (sim=0.603): What is the gender of the seventh person in your household?...
#      ✓ gndr9 (sim=0.602): What is the gender of the ninth person in your household?...
#      ✓ gndr11 (sim=0.598): What is the gender of the eleventh person in your household?...
#      ✓ gndr12 (sim=0.581): What is the gender of the twelfth person in your household?...
#
# --- Target: c19mcpnt ---
#   Question: Compared with before the coronavirus pandemic, do you now communicate online or ...
#
#   ❌ EXCLUDED features (2):
#      • c19mco12 (sim=0.927): Compared with before the coronavirus pandemic, would you say you communicate onl...
#      • c19mcwrk (sim=0.869): Compared with before the coronavirus pandemic, how often do you now communicate ...
#
#   ℹ️  Top 10 most similar features (for review):
#      ❌ c19mco12 (sim=0.927): Compared with before the coronavirus pandemic, would you say you communicate onl...
#      ❌ c19mcwrk (sim=0.869): Compared with before the coronavirus pandemic, how often do you now communicate ...
#      ✓ c19spo12 (sim=0.775): Compared with before the coronavirus pandemic, when you're physically together w...
#      ✓ c19sppnt (sim=0.772): Compared with before the coronavirus pandemic, when you're physically in the sam...
#      ✓ compnt (sim=0.702): How often do you communicate with your parent via text, email, or messaging apps...
#      ✓ c19spwrk (sim=0.685): Compared with before the coronavirus pandemic, how often do you now speak in per...
#      ✓ como12 (sim=0.642): How often do you communicate with your child who is 12 or older by text, email, ...
#      ✓ c19whome (sim=0.616): Compared with before the coronavirus pandemic, would you say you work from home ...
#      ✓ phonepnt (sim=0.591): How often do you speak with a parent by phone or on another device? Please inclu...
#      ✓ mcinter (sim=0.583): How much do online and mobile communications cause your work and personal life t...
#
# --- Target: mnactp ---
#   Question: How would you describe your partner's main activity in the past 7 days?...
#
#   ✓ No features excluded by similarity filtering
#
#   ℹ️  Top 10 most similar features (for review):
#      ✓ mainact (sim=0.692): What was your main activity during the past seven days?...
#      ✓ mnactic (sim=0.667): What was your main activity in the last 7 days?...
#      ✓ hswrkp (sim=0.642): In the last 7 days, did your partner do any of the following? For each item, ple...
#      ✓ rshpsts (sim=0.572): How would you describe your relationship with the husband, wife, or partner you ...
#      ✓ rtrdp (sim=0.548): In the last 7 days, was your partner retired?...
#      ✓ crpdwkp (sim=0.524): Did your partner do any paid work (for at least one hour) in the past 7 days?...
#      ✓ cmsrvp (sim=0.518): In the past 7 days, was your partner doing community service or serving in the m...
#      ✓ dsbldp (sim=0.500): In the past 7 days, has your partner been permanently sick or disabled?...
#      ✓ uemplap (sim=0.498): In the past 7 days, was your partner unemployed and actively looking for work?...
#      ✓ pdwrkp (sim=0.497): In the past 7 days, was your partner engaged in paid work (including if they wer...
#
# --- Target: trstplt ---
#   Question: How much do you personally trust politicians?...
#
#   ❌ EXCLUDED features (1):
#      • trstprt (sim=0.813): How much do you personally trust political parties?...
#
#   ℹ️  Top 10 most similar features (for review):
#      ❌ trstprt (sim=0.813): How much do you personally trust political parties?...
#      ✓ trstprl (sim=0.744): How much do you personally trust your country's parliament?...
#      ✓ trstep (sim=0.689): How much do you personally trust the European Parliament?...
#      ✓ trstsci (sim=0.645): How much do you personally trust scientists?...
#      ✓ ppltrst (sim=0.638): Generally speaking, how much do you trust other people — would you say most peop...
#      ✓ trstplc (sim=0.590): How much do you personally trust the police?...
#      ✓ trstlgl (sim=0.583): How much do you personally trust the legal system?...
#      ✓ cptppola (sim=0.564): How confident are you in your ability to participate in politics?...
#      ✓ trstun (sim=0.559): How much do you personally trust the United Nations?...
#      ✓ psppipla (sim=0.548): How much does the political system in this country allow people like you to infl...
#
# --- Target: eisced ---
#   Question: What is the highest level of education you have completed?...
#
#   ❌ EXCLUDED features (40):
#      • edlvdme (sim=1.000): What is the highest level of education you have completed?...
#      • edulvlb (sim=1.000): What is the highest level of education you have completed?...
#      • edlveit (sim=1.000): What is the highest level of education you have completed?...
#      • edlvdmk (sim=0.972): What is your highest completed level of education?...
#      • edubgb2 (sim=0.890): What is the highest level of education you have completed in the United Kingdom?...
#      • educgb1 (sim=0.886): What is the highest level of education you've completed in the United Kingdom?...
#      • edlvdie (sim=0.852): What is the highest level of education you have completed in Ireland?...
#      • edlvenl (sim=0.845): What is the highest level of education you have completed in the Netherlands?...
#      • edlvegr (sim=0.822): What's the highest level of education you've completed in Greece?...
#      • edlvdch (sim=0.817): What is the highest level of education you have completed in Switzerland?...
#      ... and 30 more
#
#   ℹ️  Top 10 most similar features (for review):
#      ❌ edulvlb (sim=1.000): What is the highest level of education you have completed?...
#      ❌ edlvdme (sim=1.000): What is the highest level of education you have completed?...
#      ❌ edlveit (sim=1.000): What is the highest level of education you have completed?...
#      ❌ edlvdmk (sim=0.972): What is your highest completed level of education?...
#      ❌ edubgb2 (sim=0.890): What is the highest level of education you have completed in the United Kingdom?...
#      ❌ educgb1 (sim=0.886): What is the highest level of education you've completed in the United Kingdom?...
#      ❌ edlvdie (sim=0.852): What is the highest level of education you have completed in Ireland?...
#      ❌ edlvenl (sim=0.845): What is the highest level of education you have completed in the Netherlands?...
#      ❌ edlvegr (sim=0.822): What's the highest level of education you've completed in Greece?...
#      ❌ edlvdch (sim=0.817): What is the highest level of education you have completed in Switzerland?...
#
# --- Target: health ---
#   Question: How would you describe your health in general?...
#
#   ✓ No features excluded by similarity filtering
#
#   ℹ️  Top 10 most similar features (for review):
#      ✓ rshpsts (sim=0.445): How would you describe your relationship with the husband, wife, or partner you ...
#      ✓ hlthhmp (sim=0.415): Are you limited in your daily activities by any longstanding illness, disability...
#      ✓ stfhlth (sim=0.410): Overall, how would you rate the state of health services in your country nowaday...
#      ✓ mnactp (sim=0.409): How would you describe your partner's main activity in the past 7 days?...
#      ✓ dsbld (sim=0.390): In the past 7 days, have you been permanently sick or disabled?...
#      ✓ happy (sim=0.384): Taking all things together, how happy would you say you are?...
#      ✓ occm14b (sim=0.374): How would you describe the type of occupation of your mother when you were 14 ye...
#      ✓ iphlppl (sim=0.373): How well does this statement describe you: 'It is very important to me to help t...
#      ✓ impenv (sim=0.372): To what extent does this description apply to you: "I strongly believe that peop...
#      ✓ govpriph (sim=0.356): When deciding policy, to what extent should the government prioritise public hea...
#
# --- Target: eiscedm ---
#   Question: What is the highest level of education your mother completed?...
#
#   ❌ EXCLUDED features (42):
#      • edlvmdlt (sim=1.000): What is the highest level of education your mother completed?...
#      • edlvmesi (sim=1.000): What is the highest level of education your mother completed?...
#      • edlvmdfi (sim=1.000): What is the highest level of education your mother completed?...
#      • edlvmdme (sim=1.000): What is the highest level of education your mother completed?...
#      • edulvlmb (sim=1.000): What is the highest level of education your mother completed?...
#      • edlvmdis (sim=1.000): What is the highest level of education your mother completed?...
#      • edlvmebg (sim=1.000): What is the highest level of education your mother completed?...
#      • edlvmeit (sim=0.996): What is the highest level of education your mother has completed?...
#      • edlvmeno (sim=0.996): What is the highest level of education your mother has completed?...
#      • edlvmegr (sim=0.996): What is the highest level of education your mother has completed?...
#      ... and 32 more
#
#   ℹ️  Top 10 most similar features (for review):
#      ❌ edlvmdis (sim=1.000): What is the highest level of education your mother completed?...
#      ❌ edlvmdlt (sim=1.000): What is the highest level of education your mother completed?...
#      ❌ edlvmesi (sim=1.000): What is the highest level of education your mother completed?...
#      ❌ edlvmdfi (sim=1.000): What is the highest level of education your mother completed?...
#      ❌ edulvlmb (sim=1.000): What is the highest level of education your mother completed?...
#      ❌ edlvmdme (sim=1.000): What is the highest level of education your mother completed?...
#      ❌ edlvmebg (sim=1.000): What is the highest level of education your mother completed?...
#      ❌ edlvmeit (sim=0.996): What is the highest level of education your mother has completed?...
#      ❌ edlvmegr (sim=0.996): What is the highest level of education your mother has completed?...
#      ❌ edlvmeno (sim=0.996): What is the highest level of education your mother has completed?...
#
# --- Target: hincsrca ---
#   Question: What is your household's main source of income? Please include income from all h...
#
#   ✓ No features excluded by similarity filtering
#
#   ℹ️  Top 10 most similar features (for review):
#      ✓ hinctnta (sim=0.603): Which letter best describes where your household's total income (from all source...
#      ✓ hincfel (sim=0.560): How do you feel about your household's income these days?...
#      ✓ hhmmb (sim=0.524): Including yourself and any children, how many people usually live in this househ...
#      ✓ rshipa10 (sim=0.476): How is the tenth person in your household related to you?...
#      ✓ gndr10 (sim=0.408): What is the gender of the tenth person in your household, if there is one?...
#      ✓ emprelp (sim=0.392): In their main job, is your partner an employee, self-employed, or working for th...
#      ✓ rshipa12 (sim=0.389): How is the twelfth person in your household related to you?...
#      ✓ estsz (sim=0.384): About how many people, including yourself, are or were employed at the place whe...
#      ✓ rshipa2 (sim=0.379): How is the second person in your household related to you?...
#      ✓ emplrel (sim=0.376): In your main job, were you an employee, self-employed, or working for your own f...
#
# --- Target: hincfel ---
#   Question: How do you feel about your household's income these days?...
#
#   ✓ No features excluded by similarity filtering
#
#   ℹ️  Top 10 most similar features (for review):
#      ✓ hhmmb (sim=0.583): Including yourself and any children, how many people usually live in this househ...
#      ✓ hincsrca (sim=0.560): What is your household's main source of income? Please include income from all h...
#      ✓ stfeco (sim=0.530): Overall, how satisfied are you with the current state of the economy in this cou...
#      ✓ jbprtfp (sim=0.530): How often does your job keep you from spending as much time as you'd like with y...
#      ✓ stflife (sim=0.517): Overall, how satisfied are you with your life as a whole nowadays?...
#      ✓ gincdif (sim=0.485): Do you agree or disagree that the government should take measures to reduce inco...
#      ✓ rshipa10 (sim=0.480): How is the tenth person in your household related to you?...
#      ✓ pfmfdjba (sim=0.463): How often do your partner or family members get fed up with the pressure your jo...
#      ✓ gvjobc19 (sim=0.449): How satisfied are you with the government's response in this country regarding s...
#      ✓ rshpsmk (sim=0.443): What is your relationship to the husband, wife, or partner you are currently liv...
#
# --- Target: uempla ---
#   Question: In the past 7 days, were you unemployed and actively looking for a job?...
#
#   ❌ EXCLUDED features (1):
#      • uempli (sim=0.961): In the past 7 days, were you unemployed, wanted a job, but were not actively loo...
#
#   ℹ️  Top 10 most similar features (for review):
#      ❌ uempli (sim=0.961): In the past 7 days, were you unemployed, wanted a job, but were not actively loo...
#      ✓ uemplap (sim=0.794): In the past 7 days, was your partner unemployed and actively looking for work?...
#      ✓ uemp3m (sim=0.786): Have you ever been unemployed and looking for work for more than three months?...
#      ✓ uemplip (sim=0.744): In the past 7 days, has your partner been unemployed, wanted a job, but not been...
#      ✓ uemp12m (sim=0.724): Have you had any periods of unemployment or job searching that lasted 12 months ...
#      ✓ uemp5yr (sim=0.723): In the past five years, have you had any periods when you were unemployed and lo...
#      ✓ pdwrk (sim=0.648): In the past 7 days, did you do any paid work, such as working as an employee, be...
#      ✓ crpdwk (sim=0.647): In the past seven days, did you do any paid work that lasted at least one hour?...
#      ✓ rtrd (sim=0.636): In the past 7 days, were you retired?...
#      ✓ edctn (sim=0.562): In the last 7 days, did you participate in any education or training that was no...
#
# --- Target: happy ---
#   Question: Taking all things together, how happy would you say you are?...
#
#   ✓ No features excluded by similarity filtering
#
#   ℹ️  Top 10 most similar features (for review):
#      ✓ stflife (sim=0.584): Overall, how satisfied are you with your life as a whole nowadays?...
#      ✓ impdiff (sim=0.489): How much does this description sound like you: "I like surprises, I'm always loo...
#      ✓ ipsuces (sim=0.474): How well does this description match you: being very successful is important to ...
#      ✓ stfeco (sim=0.456): Overall, how satisfied are you with the current state of the economy in this cou...
#      ✓ iphlppl (sim=0.439): How well does this statement describe you: 'It is very important to me to help t...
#      ✓ ipcrtiv (sim=0.433): How well does this description apply to you: "Thinking up new ideas and being cr...
#      ✓ ipgdtim (sim=0.428): How much does this description sound like you: "Having a good time is important ...
#      ✓ ipmodst (sim=0.420): How much does this description describe you: "It's important to be humble and mo...
#      ✓ impfun (sim=0.418): How much does this description fit you: 'Seeks every chance to have fun and thin...
#      ✓ rlgdgr (sim=0.404): Regardless of whether you belong to a particular religion, how religious would y...
#
# --- Target: wrkresp ---
#   Question: How often are employees in your organisation expected to respond to work communi...
#
#   ✓ No features excluded by similarity filtering
#
#   ℹ️  Top 10 most similar features (for review):
#      ✓ wrklong (sim=0.640): If you work in an organisation, how often are employees expected to work overtim...
#      ✓ colcom (sim=0.615): How often do you communicate in writing with your colleagues about work via text...
#      ✓ mancom (sim=0.611): How often do you communicate in writing with your line manager about work (for e...
#      ✓ colspeak (sim=0.597): How often do you talk about work with your colleagues in person? Please include ...
#      ✓ wrkhome (sim=0.581): How often do you work from home or from another location of your choice during y...
#      ✓ manspeak (sim=0.570): How often do you speak about work in person with your line manager? Please inclu...
#      ✓ mcinter (sim=0.556): How much do online and mobile communications cause your work and personal life t...
#      ✓ colscrn (sim=0.553): How often do you talk about work with colleagues when you meet on a screen (for ...
#      ✓ manwrkpl (sim=0.550): How often are you and your line manager at the same physical workplace at the sa...
#      ✓ c19mcwrk (sim=0.548): Compared with before the coronavirus pandemic, how often do you now communicate ...
#
# --- Target: polintr ---
#   Question: How interested would you say you are in politics?...
#
#   ✓ No features excluded by similarity filtering
#
#   ℹ️  Top 10 most similar features (for review):
#      ✓ cptppola (sim=0.687): How confident are you in your ability to participate in politics?...
#      ✓ actrolga (sim=0.608): How able would you say you are to take an active role in a group involved in pol...
#      ✓ lrscale (sim=0.563): Where would you place yourself on the political spectrum, from left to right?...
#      ✓ psppipla (sim=0.558): How much does the political system in this country allow people like you to infl...
#      ✓ psppsgva (sim=0.480): How much does the political system in this country allow people like you to have...
#      ✓ contplt (sim=0.479): In the past 12 months, have you contacted a politician or a national or local go...
#      ✓ pstplonl (sim=0.464): In the past 12 months, have you posted or shared anything about politics online—...
#      ✓ trstprt (sim=0.462): How much do you personally trust political parties?...
#      ✓ clsprty (sim=0.455): Do you feel closer to any one political party than to the others?...
#      ✓ trstplt (sim=0.447): How much do you personally trust politicians?...
#
# --- Target: loylead ---
#   Question: How much do you agree or disagree with the statement: "What this country needs m...
#
#   ✓ No features excluded by similarity filtering
#
#   ℹ️  Top 10 most similar features (for review):
#      ✓ iplylfr (sim=0.545): How well does the following statement describe you: "It is important to be loyal...
#      ✓ ipstrgv (sim=0.474): How much does this description sound like you: 'You think it's important that th...
#      ✓ secgrdec (sim=0.462): To what extent do you agree or disagree with the statement: "A small secret grou...
#      ✓ accalaw (sim=0.457): How acceptable would it be for a strong leader in this country to be above the l...
#      ✓ stfdem (sim=0.454): Overall, how satisfied are you with the way democracy works in this country?...
#      ✓ impdema (sim=0.446): What do you think is the most important for democracy in general?...
#      ✓ impdemc (sim=0.446): What do you think is the most important for democracy in general?...
#      ✓ impdemd (sim=0.446): What do you think is the most important for democracy in general?...
#      ✓ impdemb (sim=0.446): What do you think is the most important for democracy in general?...
#      ✓ iprspot (sim=0.440): How well does this statement describe you: "It is important to me to get respect...
#
# --- Target: impdema ---
#   Question: What do you think is the most important for democracy in general?...
#
#   ❌ EXCLUDED features (4):
#      • impdemb (sim=1.000): What do you think is the most important for democracy in general?...
#      • impdemc (sim=1.000): What do you think is the most important for democracy in general?...
#      • impdemd (sim=1.000): What do you think is the most important for democracy in general?...
#      • impdeme (sim=0.980): What do you think is most important for democracy?...
#
#   ℹ️  Top 10 most similar features (for review):
#      ❌ impdemc (sim=1.000): What do you think is the most important for democracy in general?...
#      ❌ impdemd (sim=1.000): What do you think is the most important for democracy in general?...
#      ❌ impdemb (sim=1.000): What do you think is the most important for democracy in general?...
#      ❌ impdeme (sim=0.980): What do you think is most important for democracy?...
#      ✓ implvdm (sim=0.716): How important is it to you to live in a country that is governed democratically?...
#      ✓ viepol (sim=0.687): How important for democracy is it that ordinary people's views prevail over thos...
#      ✓ chpldmi (sim=0.662): How important do you think it is for democracy that the government changes its p...
#      ✓ wpestop (sim=0.662): Thinking generally, how important is it for democracy that the will of the peopl...
#      ✓ grdfinc (sim=0.657): How important do you think it is for democracy that the government takes measure...
#      ✓ dfprtal (sim=0.649): How important do you think it is for democracy in general that different politic...
#
# --- Target: psppsgva ---
#   Question: How much does the political system in this country allow people like you to have...
#
#   ❌ EXCLUDED features (1):
#      • psppipla (sim=0.803): How much does the political system in this country allow people like you to infl...
#
#   ℹ️  Top 10 most similar features (for review):
#      ❌ psppipla (sim=0.803): How much does the political system in this country allow people like you to infl...
#      ✓ medcrgvc (sim=0.561): How free do you think the media in this country are to criticise the government?...
#      ✓ trstprl (sim=0.558): How much do you personally trust your country's parliament?...
#      ✓ stpldmc (sim=0.549): How often do you think the government in this country follows through on its pla...
#      ✓ chpldmc (sim=0.528): How often do you think the government in this country changes its planned polici...
#      ✓ votedirc (sim=0.513): How much do you think citizens in this country have the final say on the most im...
#      ✓ gptpelcc (sim=0.511): When governing parties have done a bad job, how much are they punished in electi...
#      ✓ stpldmi (sim=0.499): How important is it for democracy that the government sticks to its planned poli...
#      ✓ medcrgv (sim=0.495): How important is it for democracy that the media are free to criticise the gover...
#      ✓ stfdem (sim=0.493): Overall, how satisfied are you with the way democracy works in this country?...
#
# --- Target: chpldmc ---
#   Question: How often do you think the government in this country changes its planned polici...
#
#   ❌ EXCLUDED features (1):
#      • stpldmc (sim=0.886): How often do you think the government in this country follows through on its pla...
#
#   ℹ️  Top 10 most similar features (for review):
#      ❌ stpldmc (sim=0.886): How often do you think the government in this country follows through on its pla...
#      ✓ chpldmi (sim=0.762): How important do you think it is for democracy that the government changes its p...
#      ✓ stpldmi (sim=0.657): How important is it for democracy that the government sticks to its planned poli...
#      ✓ chpldm (sim=0.549): Sometimes the government disagrees with what most people think is best. What do ...
#      ✓ psppsgva (sim=0.528): How much does the political system in this country allow people like you to have...
#      ✓ keydecc (sim=0.497): To what extent do you think key decisions in this country are made by the nation...
#      ✓ govpriph (sim=0.483): When deciding policy, to what extent should the government prioritise public hea...
#      ✓ stfgov (sim=0.477): How satisfied are you with the way the national government is doing its job?...
#      ✓ testii9 (sim=0.466): How likely do you think it is that enough governments will take action to reduce...
#      ✓ testic39 (sim=0.465): How likely do you think it is that governments in enough countries will take act...
#
# --- Target: govpriph ---
#   Question: When deciding policy, to what extent should the government prioritise public hea...
#
#   ✓ No features excluded by similarity filtering
#
#   ℹ️  Top 10 most similar features (for review):
#      ✓ panpriph (sim=0.715): When fighting a pandemic, how much should priority be given to public health ver...
#      ✓ panmonpb (sim=0.555): When fighting a pandemic, how would you balance the priority between government ...
#      ✓ stfhlth (sim=0.545): Overall, how would you rate the state of health services in your country nowaday...
#      ✓ panfolru (sim=0.543): To what extent do you prefer following government rules versus making your own d...
#      ✓ gvbalc19 (sim=0.537): How well did the government in this country balance protecting the economy and p...
#      ✓ chpldmi (sim=0.502): How important do you think it is for democracy that the government changes its p...
#      ✓ gvimpc19 (sim=0.501): How much do you trust the national government in this country to handle the impa...
#      ✓ chpldm (sim=0.491): Sometimes the government disagrees with what most people think is best. What do ...
#      ✓ govmonpb (sim=0.487): When you think about government priorities, which is more important: monitoring ...
#      ✓ chpldmc (sim=0.483): How often do you think the government in this country changes its planned polici...
#
# --- Target: vote ---
#   Question: Did you vote in the last national election?...
#
#   ✓ No features excluded by similarity filtering
#
#   ℹ️  Top 10 most similar features (for review):
#      ✓ prtvclt1 (sim=0.705): In the most recent national election, which party did you vote for with your fir...
#      ✓ prtvthnl (sim=0.699): Which party did you vote for in the last national election in the Netherlands?...
#      ✓ prtvtbno (sim=0.680): Which party did you vote for in the last national election in Norway?...
#      ✓ prtvtefi (sim=0.674): Which party did you vote for in the last national election in Finland?...
#      ✓ prtvtecz (sim=0.670): Which party did you vote for in the last national election in the Czech Republic...
#      ✓ prtvthch (sim=0.670): Which party did you vote for in the last national election in Switzerland?...
#      ✓ prtvtfsi (sim=0.662): Which party did you vote for in the last national election in Slovenia?...
#      ✓ prtvtdit (sim=0.662): Which party did you vote for in the last national election in Italy?...
#      ✓ prtvtesk (sim=0.660): Which party did you vote for in the last national election in Slovakia?...
#      ✓ prtvtdgb (sim=0.659): Which party did you vote for in the most recent national election in the United ...
#
# --- Target: volunfp ---
#   Question: In the past 12 months, have you volunteered for a not-for-profit or charitable o...
#
#   ✓ No features excluded by similarity filtering
#
#   ℹ️  Top 10 most similar features (for review):
#      ✓ donprty (sim=0.669): In the past 12 months, did you donate money to or take part in activities of a p...
#      ✓ pbldmna (sim=0.526): In the last 12 months, have you taken part in a public demonstration in this cou...
#      ✓ contplt (sim=0.483): In the past 12 months, have you contacted a politician or a national or local go...
#      ✓ hswrk (sim=0.472): In the last 7 days, did you do any of the following: housework, look after child...
#      ✓ cmsrv (sim=0.452): In the past 7 days, did any of the following apply to your community or military...
#      ✓ tporgwk (sim=0.447): Which type of organisation do or did you work for?...
#      ✓ pdjobev (sim=0.430): Have you ever had a paid job?...
#      ✓ emplno (sim=0.426): How many employees, if any, do or did you have?...
#      ✓ badge (sim=0.422): In the past 12 months, have you worn or displayed a campaign badge or sticker?...
#      ✓ uemp3m (sim=0.418): Have you ever been unemployed and looking for work for more than three months?...
#
# --- Target: ipudrst ---
#   Question: To what extent does this describe you: "It's important to listen to people who a...
#
#   ✓ No features excluded by similarity filtering
#
#   ℹ️  Top 10 most similar features (for review):
#      ✓ iprspot (sim=0.561): How well does this statement describe you: "It is important to me to get respect...
#      ✓ ipbhprp (sim=0.472): How much does this statement describe you: 'I think it's important to always beh...
#      ✓ ipeqopt (sim=0.446): To what extent does this person share your belief that everyone should be treate...
#      ✓ ipfrule (sim=0.438): How much does this description sound like you: "This person believes that people...
#      ✓ ipmodst (sim=0.427): How much does this description describe you: "It's important to be humble and mo...
#      ✓ impfree (sim=0.390): To what extent does the following description sound like you: 'It is important t...
#      ✓ iplylfr (sim=0.379): How well does the following statement describe you: "It is important to be loyal...
#      ✓ iphlppl (sim=0.361): How well does this statement describe you: 'It is very important to me to help t...
#      ✓ feethngr (sim=0.351): Do you feel you are part of the same racial or ethnic group as most people in th...
#      ✓ dscrgrp (sim=0.341): Do you consider yourself a member of a group that is discriminated against in th...
#
# --- Target: fairelcc ---
#   Question: To what extent do you think national elections in this country are free and fair...
#
#   ❌ EXCLUDED features (1):
#      • fairelc (sim=0.866): How important is it for democracy overall that national elections are free and f...
#
#   ℹ️  Top 10 most similar features (for review):
#      ❌ fairelc (sim=0.866): How important is it for democracy overall that national elections are free and f...
#      ✓ medcrgvc (sim=0.565): How free do you think the media in this country are to criticise the government?...
#      ✓ gptpelcc (sim=0.554): When governing parties have done a bad job, how much are they punished in electi...
#      ✓ gptpelc (sim=0.523): Overall, how important for democracy is it that voters punish governing parties ...
#      ✓ medcrgv (sim=0.490): How important is it for democracy that the media are free to criticise the gover...
#      ✓ stfdem (sim=0.469): Overall, how satisfied are you with the way democracy works in this country?...
#      ✓ votedirc (sim=0.459): How much do you think citizens in this country have the final say on the most im...
#      ✓ psppsgva (sim=0.449): How much does the political system in this country allow people like you to have...
#      ✓ dfprtal (sim=0.442): How important do you think it is for democracy in general that different politic...
#      ✓ trstprl (sim=0.441): How much do you personally trust your country's parliament?...
#
# --- Target: imprich ---
#   Question: To what extent does this statement describe you: 'Being rich and having a lot of...
#
#   ✓ No features excluded by similarity filtering
#
#   ℹ️  Top 10 most similar features (for review):
#      ✓ iphlppl (sim=0.630): How well does this statement describe you: 'It is very important to me to help t...
#      ✓ impfree (sim=0.571): To what extent does the following description sound like you: 'It is important t...
#      ✓ iplylfr (sim=0.535): How well does the following statement describe you: "It is important to be loyal...
#      ✓ ipbhprp (sim=0.520): How much does this statement describe you: 'I think it's important to always beh...
#      ✓ ipmodst (sim=0.508): How much does this description describe you: "It's important to be humble and mo...
#      ✓ ipsuces (sim=0.503): How well does this description match you: being very successful is important to ...
#      ✓ impsafe (sim=0.491): How well does this statement describe you: "It's important for me to live in sec...
#      ✓ ipgdtim (sim=0.485): How much does this description sound like you: "Having a good time is important ...
#      ✓ iprspot (sim=0.477): How well does this statement describe you: "It is important to me to get respect...
#      ✓ impenv (sim=0.474): To what extent does this description apply to you: "I strongly believe that peop...
#
# --- Target: stfeco ---
#   Question: Overall, how satisfied are you with the current state of the economy in this cou...
#
#   ✓ No features excluded by similarity filtering
#
#   ℹ️  Top 10 most similar features (for review):
#      ✓ stflife (sim=0.714): Overall, how satisfied are you with your life as a whole nowadays?...
#      ✓ stfgov (sim=0.709): How satisfied are you with the way the national government is doing its job?...
#      ✓ stfdem (sim=0.667): Overall, how satisfied are you with the way democracy works in this country?...
#      ✓ gvhanc19 (sim=0.549): Overall, how satisfied are you with how the government in this country handled t...
#      ✓ imbgeco (sim=0.544): How good or bad for this country's economy is it when people come to live here f...
#      ✓ hincfel (sim=0.530): How do you feel about your household's income these days?...
#      ✓ gvjobc19 (sim=0.521): How satisfied are you with the government's response in this country regarding s...
#      ✓ stfhlth (sim=0.500): Overall, how would you rate the state of health services in your country nowaday...
#      ✓ stfedu (sim=0.494): How would you rate the state of education in this country nowadays?...
#      ✓ cntry (sim=0.477): Which country are you currently in?...
#
# --- Target: impenv ---
#   Question: To what extent does this description apply to you: "I strongly believe that peop...
#
#   ✓ No features excluded by similarity filtering
#
#   ℹ️  Top 10 most similar features (for review):
#      ✓ iphlppl (sim=0.612): How well does this statement describe you: 'It is very important to me to help t...
#      ✓ impsafe (sim=0.592): How well does this statement describe you: "It's important for me to live in sec...
#      ✓ ipbhprp (sim=0.479): How much does this statement describe you: 'I think it's important to always beh...
#      ✓ imprich (sim=0.474): To what extent does this statement describe you: 'Being rich and having a lot of...
#      ✓ impfree (sim=0.463): To what extent does the following description sound like you: 'It is important t...
#      ✓ ccrdprs (sim=0.459): How much personal responsibility do you feel to take action to reduce climate ch...
#      ✓ impfun (sim=0.457): How much does this description fit you: 'Seeks every chance to have fun and thin...
#      ✓ ipmodst (sim=0.437): How much does this description describe you: "It's important to be humble and mo...
#      ✓ iprspot (sim=0.437): How well does this statement describe you: "It is important to me to get respect...
#      ✓ iplylfr (sim=0.432): How well does the following statement describe you: "It is important to be loyal...

# %%
#@title Manual leakage check: Look for obviously related questions
# This catches things semantic similarity might miss

def manual_leakage_check(metadata: dict, target_codes: list) -> None:
    """
    Flag potential leakage based on keyword matching.

    This is a safety net for cases where:
    - Semantic model isn't loaded
    - Questions are phrased differently but measure same construct
    """

    # Get target keywords
    target_keywords = {}
    for target in target_codes:
        for section, variables in metadata.items():
            if target in variables:
                q = variables[target].get('question', '').lower()
                # Extract key terms
                keywords = set()
                for word in q.split():
                    if len(word) > 4:  # Skip short words
                        keywords.add(word.strip('?.,!'))
                target_keywords[target] = keywords
                break

    print("="*70)
    print("MANUAL LEAKAGE CHECK (Keyword-based)")
    print("="*70)

    for target, keywords in target_keywords.items():
        print(f"\n--- Target: {target} ---")
        print(f"  Keywords: {keywords}")

        matches = []
        for section, variables in metadata.items():
            for var_code, var_data in variables.items():
                if var_code == target:
                    continue
                q = var_data.get('question', '').lower()
                overlap = keywords & set(w.strip('?.,!') for w in q.split() if len(w) > 4)
                if len(overlap) >= 2:  # At least 2 keyword matches
                    matches.append((var_code, overlap, q[:60]))

        if matches:
            print(f"\n  ⚠️  Potential leakage ({len(matches)} features):")
            for var_code, overlap, q_text in matches[:10]:
                print(f"     • {var_code}: {q_text}...")
                print(f"       Matching keywords: {overlap}")
        else:
            print(f"\n  ✓ No obvious keyword matches found")


manual_leakage_check(metadata, TARGET_CODES)
# Out:
# ======================================================================
# MANUAL LEAKAGE CHECK (Keyword-based)
# ======================================================================
#
# --- Target: gndr ---
#   Keywords: {'gender'}
#
#   ✓ No obvious keyword matches found
#
# --- Target: c19mcpnt ---
#   Keywords: {'about', 'before', 'same', 'parent(s)', 'pandemic', 'coronavirus', 'mobile', 'online', 'compared', 'often', 'communicate'}
#
#   ⚠️  Potential leakage (33 features):
#      • como12: how often do you communicate with your child who is 12 or ol...
#        Matching keywords: {'communicate', 'often'}
#      • colprop: thinking about the colleagues you work with regularly, on a ...
#        Matching keywords: {'about', 'often'}
#      • mcmsinf: how much do you think online and mobile communication expose...
#        Matching keywords: {'mobile', 'online'}
#      • mcclose: how much do online and mobile communications make people fee...
#        Matching keywords: {'mobile', 'online'}
#      • mcinter: how much do online and mobile communications cause your work...
#        Matching keywords: {'mobile', 'online'}
#      • mcpriv: to what extent do online and mobile communications undermine...
#        Matching keywords: {'mobile', 'online'}
#      • compnt: how often do you communicate with your parent via text, emai...
#        Matching keywords: {'communicate', 'often'}
#      • manspeak: how often do you speak about work in person with your line m...
#        Matching keywords: {'about', 'often'}
#      • manscrn: how often do you talk about work with your line manager in v...
#        Matching keywords: {'about', 'often'}
#      • manphone: how often do you talk about work with your line manager by p...
#        Matching keywords: {'about', 'often'}
#
# --- Target: mnactp ---
#   Keywords: {'activity', 'describe', 'would', "partner's", 'days'}
#
#   ⚠️  Potential leakage (7 features):
#      • health: how would you describe your health in general?...
#        Matching keywords: {'would', 'describe'}
#      • rshpsts: how would you describe your relationship with the husband, w...
#        Matching keywords: {'would', 'describe'}
#      • marstgb: how would you describe your current legal marital status?...
#        Matching keywords: {'would', 'describe'}
#      • mainact: what was your main activity during the past seven days?...
#        Matching keywords: {'activity', 'days'}
#      • mnactic: what was your main activity in the last 7 days?...
#        Matching keywords: {'activity', 'days'}
#      • occm14b: how would you describe the type of occupation of your mother...
#        Matching keywords: {'would', 'describe'}
#      • ipbhprp: how much does this statement describe you: 'i think it's imp...
#        Matching keywords: {'would', 'describe'}
#
# --- Target: trstplt ---
#   Keywords: {'personally', 'politicians', 'trust'}
#
#   ⚠️  Potential leakage (7 features):
#      • trstsci: how much do you personally trust scientists?...
#        Matching keywords: {'personally', 'trust'}
#      • trstprl: how much do you personally trust your country's parliament?...
#        Matching keywords: {'personally', 'trust'}
#      • trstlgl: how much do you personally trust the legal system?...
#        Matching keywords: {'personally', 'trust'}
#      • trstplc: how much do you personally trust the police?...
#        Matching keywords: {'personally', 'trust'}
#      • trstprt: how much do you personally trust political parties?...
#        Matching keywords: {'personally', 'trust'}
#      • trstep: how much do you personally trust the european parliament?...
#        Matching keywords: {'personally', 'trust'}
#      • trstun: how much do you personally trust the united nations?...
#        Matching keywords: {'personally', 'trust'}
#
# --- Target: eisced ---
#   Keywords: {'completed', 'level', 'education', 'highest'}
#
#   ⚠️  Potential leakage (100 features):
#      • edulvlb: what is the highest level of education you have completed?...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#      • edlvebe: what is the highest level of education you have completed in...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#      • edlvebg: what is the highest level of education you have completed in...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#      • edlvdch: what is the highest level of education you have completed in...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#      • edlvehr: what is the highest level of education you have completed in...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#      • edlvdcz: what is the highest level of education you have completed in...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#      • edlvdee: what's the highest level of education you've completed in es...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#      • edlvdfi: what is the highest level of education you have successfully...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#      • edlvdfr: what's the highest level of education you completed in franc...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#      • edlvegr: what's the highest level of education you've completed in gr...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#
# --- Target: health ---
#   Keywords: {'general', 'health', 'would', 'describe'}
#
#   ⚠️  Potential leakage (6 features):
#      • rshpsts: how would you describe your relationship with the husband, w...
#        Matching keywords: {'would', 'describe'}
#      • marstgb: how would you describe your current legal marital status?...
#        Matching keywords: {'would', 'describe'}
#      • mnactp: how would you describe your partner's main activity in the p...
#        Matching keywords: {'would', 'describe'}
#      • occm14b: how would you describe the type of occupation of your mother...
#        Matching keywords: {'would', 'describe'}
#      • ipbhprp: how much does this statement describe you: 'i think it's imp...
#        Matching keywords: {'would', 'describe'}
#      • stfhlth: overall, how would you rate the state of health services in ...
#        Matching keywords: {'health', 'would'}
#
# --- Target: eiscedm ---
#   Keywords: {'level', 'mother', 'education', 'completed', 'highest'}
#
#   ⚠️  Potential leakage (101 features):
#      • edulvlb: what is the highest level of education you have completed?...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#      • eisced: what is the highest level of education you have completed?...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#      • edlvebe: what is the highest level of education you have completed in...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#      • edlvebg: what is the highest level of education you have completed in...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#      • edlvdch: what is the highest level of education you have completed in...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#      • edlvehr: what is the highest level of education you have completed in...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#      • edlvdcz: what is the highest level of education you have completed in...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#      • edlvdee: what's the highest level of education you've completed in es...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#      • edlvdfi: what is the highest level of education you have successfully...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#      • edlvdfr: what's the highest level of education you completed in franc...
#        Matching keywords: {'completed', 'level', 'education', 'highest'}
#
# --- Target: hincsrca ---
#   Keywords: {'members', 'income', 'source', 'please', 'received', 'household', 'include', "household's", 'whole'}
#
#   ⚠️  Potential leakage (7 features):
#      • pdwrk: in the past 7 days, did you do any paid work, such as workin...
#        Matching keywords: {'please', 'include'}
#      • hinctnta: which letter best describes where your household's total inc...
#        Matching keywords: {"household's", 'please', 'income'}
#      • chldo12: how many children aged 12 or older do you have? please inclu...
#        Matching keywords: {'please', 'include'}
#      • phonepnt: how often do you speak with a parent by phone or on another ...
#        Matching keywords: {'please', 'include'}
#      • manspeak: how often do you speak about work in person with your line m...
#        Matching keywords: {'please', 'include'}
#      • colspeak: how often do you talk about work with your colleagues in per...
#        Matching keywords: {'please', 'include'}
#      • hincfel: how do you feel about your household's income these days?...
#        Matching keywords: {"household's", 'income'}
#
# --- Target: hincfel ---
#   Keywords: {'about', 'these', 'income', "household's", 'days'}
#
#   ⚠️  Potential leakage (2 features):
#      • hincsrca: what is your household's main source of income? please inclu...
#        Matching keywords: {"household's", 'income'}
#      • hinctnta: which letter best describes where your household's total inc...
#        Matching keywords: {"household's", 'income'}
#
# --- Target: uempla ---
#   Keywords: {'looking', 'actively', 'unemployed', 'days'}
#
#   ⚠️  Potential leakage (6 features):
#      • uempli: in the past 7 days, were you unemployed, wanted a job, but w...
#        Matching keywords: {'looking', 'actively', 'unemployed', 'days'}
#      • uemp5yr: in the past five years, have you had any periods when you we...
#        Matching keywords: {'looking', 'unemployed'}
#      • uemplap: in the past 7 days, was your partner unemployed and actively...
#        Matching keywords: {'looking', 'actively', 'unemployed', 'days'}
#      • uemplip: in the past 7 days, has your partner been unemployed, wanted...
#        Matching keywords: {'looking', 'actively', 'unemployed', 'days'}
#      • hswrkp: in the last 7 days, did your partner do any of the following...
#        Matching keywords: {'looking', 'days'}
#      • uemp3m: have you ever been unemployed and looking for work for more ...
#        Matching keywords: {'looking', 'unemployed'}
#
# --- Target: happy ---
#   Keywords: {'together', 'would', 'things', 'happy', 'taking'}
#
#   ⚠️  Potential leakage (1 features):
#      • c19spo12: compared with before the coronavirus pandemic, when you're p...
#        Matching keywords: {'would', 'together'}
#
# --- Target: wrkresp ---
#   Keywords: {'outside', 'working', 'communications', 'hours', 'organisation', 'respond', 'employees', 'often', 'expected'}
#
#   ⚠️  Potential leakage (4 features):
#      • wrkhome: how often do you work from home or from another location of ...
#        Matching keywords: {'often', 'working', 'hours'}
#      • wrklong: if you work in an organisation, how often are employees expe...
#        Matching keywords: {'often', 'expected', 'organisation', 'employees'}
#      • c19whacc: compared with before the coronavirus pandemic, how accepted ...
#        Matching keywords: {'organisation', 'employees'}
#      • hapwrc19: since the start of the covid-19 pandemic, were your working ...
#        Matching keywords: {'working', 'hours'}
#
# --- Target: polintr ---
#   Keywords: {'would', 'interested', 'politics'}
#
#   ✓ No obvious keyword matches found
#
# --- Target: loylead ---
#   Keywords: {'country', 'disagree', 'loyalty', 'statement:', 'needs', '"what', 'leaders"', 'toward', 'agree'}
#
#   ⚠️  Potential leakage (8 features):
#      • freehms: to what extent do you agree or disagree with the statement: ...
#        Matching keywords: {'disagree', 'statement:', 'agree'}
#      • hmsacld: to what extent do you agree or disagree that same-sex couple...
#        Matching keywords: {'disagree', 'agree'}
#      • lrnobed: do you agree or disagree that obedience and respect for auth...
#        Matching keywords: {'disagree', 'agree'}
#      • secgrdec: to what extent do you agree or disagree with the statement: ...
#        Matching keywords: {'disagree', 'statement:', 'agree'}
#      • gincdif: do you agree or disagree that the government should take mea...
#        Matching keywords: {'disagree', 'agree'}
#      • stpldmc: how often do you think the government in this country follow...
#        Matching keywords: {'disagree', 'country'}
#      • scidecpb: do you agree or disagree that groups of scientists manipulat...
#        Matching keywords: {'disagree', 'agree'}
#      • gvconc19: to what extent do you agree or disagree that coronavirus is ...
#        Matching keywords: {'disagree', 'agree'}
#
# --- Target: impdema ---
#   Keywords: {'important', 'general', 'democracy', 'think'}
#
#   ⚠️  Potential leakage (22 features):
#      • impdiff: how much does this description sound like you: "i like surpr...
#        Matching keywords: {'important', 'think'}
#      • ipbhprp: how much does this statement describe you: 'i think it's imp...
#        Matching keywords: {'important', 'think'}
#      • fairelc: how important is it for democracy overall that national elec...
#        Matching keywords: {'important', 'democracy'}
#      • dfprtal: how important do you think it is for democracy in general th...
#        Matching keywords: {'important', 'general', 'democracy', 'think'}
#      • votedir: how important is it for democracy that citizens have the fin...
#        Matching keywords: {'important', 'democracy'}
#      • gptpelc: overall, how important for democracy is it that voters punis...
#        Matching keywords: {'important', 'democracy'}
#      • viepol: how important for democracy is it that ordinary people's vie...
#        Matching keywords: {'important', 'democracy'}
#      • wpestop: thinking generally, how important is it for democracy that t...
#        Matching keywords: {'important', 'democracy'}
#      • keydec: thinking in general, not specifically about this country, ho...
#        Matching keywords: {'important', 'general', 'democracy'}
#      • votedirc: how much do you think citizens in this country have the fina...
#        Matching keywords: {'important', 'think'}
#
# --- Target: psppsgva ---
#   Keywords: {'does', 'country', 'system', 'political', 'allow', 'people', 'government'}
#
#   ⚠️  Potential leakage (26 features):
#      • imdfetn: how many immigrants who are a different race or ethnic group...
#        Matching keywords: {'people', 'country'}
#      • feethngr: do you feel you are part of the same racial or ethnic group ...
#        Matching keywords: {'people', 'country'}
#      • imwbcnt: do people who come to live here from other countries make th...
#        Matching keywords: {'people', 'country'}
#      • psppipla: how much does the political system in this country allow peo...
#        Matching keywords: {'country', 'system', 'political', 'allow', 'people'}
#      • imsmetn: how many people of the same race or ethnic group as most peo...
#        Matching keywords: {'people', 'country'}
#      • impcntr: how many people from poorer countries outside europe should ...
#        Matching keywords: {'people', 'country'}
#      • dfprtalc: to what extent do you think the different political parties ...
#        Matching keywords: {'political', 'country'}
#      • votedirc: how much do you think citizens in this country have the fina...
#        Matching keywords: {'political', 'country'}
#      • wpestopc: to what extent does the statement "in this country, the will...
#        Matching keywords: {'people', 'country'}
#      • chpldm: sometimes the government disagrees with what most people thi...
#        Matching keywords: {'people', 'government'}
#
# --- Target: chpldmc ---
#   Keywords: {'people', 'policies', 'country', 'response', 'think', 'changes', 'often', 'planned', 'government'}
#
#   ⚠️  Potential leakage (45 features):
#      • imdfetn: how many immigrants who are a different race or ethnic group...
#        Matching keywords: {'people', 'country'}
#      • feethngr: do you feel you are part of the same racial or ethnic group ...
#        Matching keywords: {'people', 'country'}
#      • colprop: thinking about the colleagues you work with regularly, on a ...
#        Matching keywords: {'often', 'think'}
#      • mcmsinf: how much do you think online and mobile communication expose...
#        Matching keywords: {'people', 'think'}
#      • pplfair: do you think most people would try to take advantage of you ...
#        Matching keywords: {'people', 'think'}
#      • imwbcnt: do people who come to live here from other countries make th...
#        Matching keywords: {'people', 'country'}
#      • ipbhprp: how much does this statement describe you: 'i think it's imp...
#        Matching keywords: {'people', 'think'}
#      • psppipla: how much does the political system in this country allow peo...
#        Matching keywords: {'people', 'country'}
#      • imsmetn: how many people of the same race or ethnic group as most peo...
#        Matching keywords: {'people', 'country'}
#      • impcntr: how many people from poorer countries outside europe should ...
#        Matching keywords: {'people', 'country'}
#
# --- Target: govpriph ---
#   Keywords: {'activity', 'health', 'extent', 'should', 'versus', 'public', 'economic', 'prioritise', 'deciding', 'policy', 'government'}
#
#   ⚠️  Potential leakage (18 features):
#      • hlthhmp: are you limited in your daily activities by any longstanding...
#        Matching keywords: {'health', 'extent'}
#      • freehms: to what extent do you agree or disagree with the statement: ...
#        Matching keywords: {'extent', 'should'}
#      • ipeqopt: to what extent does this person share your belief that every...
#        Matching keywords: {'extent', 'should'}
#      • hmsacld: to what extent do you agree or disagree that same-sex couple...
#        Matching keywords: {'extent', 'should'}
#      • chpldm: sometimes the government disagrees with what most people thi...
#        Matching keywords: {'should', 'government'}
#      • gincdif: do you agree or disagree that the government should take mea...
#        Matching keywords: {'should', 'government'}
#      • grdfincc: to what extent does the government in this country take meas...
#        Matching keywords: {'extent', 'government'}
#      • keydecc: to what extent do you think key decisions in this country ar...
#        Matching keywords: {'extent', 'government'}
#      • iorgact: to what extent did management at your workplace allow you to...
#        Matching keywords: {'extent', 'policy'}
#      • govmonpb: when you think about government priorities, which is more im...
#        Matching keywords: {'public', 'government'}
#
# --- Target: vote ---
#   Keywords: {'national', 'election'}
#
#   ⚠️  Potential leakage (24 features):
#      • prtvtebe: in the last national election in belgium, which party did yo...
#        Matching keywords: {'national', 'election'}
#      • prtvtebg: which party did you vote for in the most recent national ele...
#        Matching keywords: {'national', 'election'}
#      • prtvthch: which party did you vote for in the last national election i...
#        Matching keywords: {'national', 'election'}
#      • prtvtbhr: which party did you vote for in the most recent national ele...
#        Matching keywords: {'national', 'election'}
#      • prtvtecz: which party did you vote for in the last national election i...
#        Matching keywords: {'national', 'election'}
#      • prtvthee: which party did you vote for in the last national election i...
#        Matching keywords: {'national', 'election'}
#      • prtvtefi: which party did you vote for in the last national election i...
#        Matching keywords: {'national', 'election'}
#      • prtvtefr: which party did you vote for in the most recent national ele...
#        Matching keywords: {'national', 'election'}
#      • prtvtdgr: which party did you vote for in the last national election i...
#        Matching keywords: {'national', 'election'}
#      • prtvtghu: which political party did you vote for in the most recent na...
#        Matching keywords: {'national', 'election'}
#
# --- Target: volunfp ---
#   Keywords: {'charitable', 'months', 'volunteered', 'not-for-profit', 'organization'}
#
#   ✓ No obvious keyword matches found
#
# --- Target: ipudrst ---
#   Keywords: {'important', 'extent', 'them', 'understand', 'disagree', 'describe', 'different', 'still', 'them"', 'listen', '"it\'s', 'people'}
#
#   ⚠️  Potential leakage (27 features):
#      • imdfetn: how many immigrants who are a different race or ethnic group...
#        Matching keywords: {'people', 'different'}
#      • impdiff: how much does this description sound like you: "i like surpr...
#        Matching keywords: {'important', 'different'}
#      • freehms: to what extent do you agree or disagree with the statement: ...
#        Matching keywords: {'extent', 'disagree'}
#      • ipmodst: how much does this description describe you: "it's important...
#        Matching keywords: {'important', '"it\'s', 'describe'}
#      • impfree: to what extent does the following description sound like you...
#        Matching keywords: {'important', 'extent'}
#      • ipsuces: how well does this description match you: being very success...
#        Matching keywords: {'important', 'people'}
#      • ppltrst: generally speaking, how much do you trust other people — wou...
#        Matching keywords: {'people', 'them'}
#      • impsafe: how well does this statement describe you: "it's important f...
#        Matching keywords: {'important', '"it\'s', 'describe'}
#      • ipbhprp: how much does this statement describe you: 'i think it's imp...
#        Matching keywords: {'important', 'people', 'describe'}
#      • iprspot: how well does this statement describe you: "it is important ...
#        Matching keywords: {'important', 'people', 'describe'}
#
# --- Target: fairelcc ---
#   Keywords: {'extent', 'country', 'elections', 'national', 'think', 'fair'}
#
#   ⚠️  Potential leakage (19 features):
#      • pplfair: do you think most people would try to take advantage of you ...
#        Matching keywords: {'fair', 'think'}
#      • fairelc: how important is it for democracy overall that national elec...
#        Matching keywords: {'national', 'fair', 'elections'}
#      • keydec: thinking in general, not specifically about this country, ho...
#        Matching keywords: {'national', 'country'}
#      • dfprtalc: to what extent do you think the different political parties ...
#        Matching keywords: {'extent', 'think', 'country'}
#      • votedirc: how much do you think citizens in this country have the fina...
#        Matching keywords: {'think', 'country'}
#      • wpestopc: to what extent does the statement "in this country, the will...
#        Matching keywords: {'extent', 'country'}
#      • gptpelcc: when governing parties have done a bad job, how much are the...
#        Matching keywords: {'elections', 'country'}
#      • grdfincc: to what extent does the government in this country take meas...
#        Matching keywords: {'extent', 'country'}
#      • keydecc: to what extent do you think key decisions in this country ar...
#        Matching keywords: {'extent', 'national', 'think', 'country'}
#      • chpldmc: how often do you think the government in this country change...
#        Matching keywords: {'think', 'country'}
#
# --- Target: imprich ---
#   Keywords: {'important', 'extent', 'statement', "'being", 'having', 'describe', 'money', 'things', 'expensive'}
#
#   ⚠️  Potential leakage (13 features):
#      • impdiff: how much does this description sound like you: "i like surpr...
#        Matching keywords: {'important', 'things'}
#      • ipcrtiv: how well does this description apply to you: "thinking up ne...
#        Matching keywords: {'important', 'things'}
#      • ipmodst: how much does this description describe you: "it's important...
#        Matching keywords: {'important', 'describe'}
#      • impfree: to what extent does the following description sound like you...
#        Matching keywords: {'important', 'extent'}
#      • impfun: how much does this description fit you: 'seeks every chance ...
#        Matching keywords: {'important', 'things'}
#      • impsafe: how well does this statement describe you: "it's important f...
#        Matching keywords: {'important', 'statement', 'things', 'describe'}
#      • ipbhprp: how much does this statement describe you: 'i think it's imp...
#        Matching keywords: {'important', 'statement', 'describe'}
#      • iprspot: how well does this statement describe you: "it is important ...
#        Matching keywords: {'important', 'statement', 'describe'}
#      • iplylfr: how well does the following statement describe you: "it is i...
#        Matching keywords: {'important', 'statement', 'describe'}
#      • wpestopc: to what extent does the statement "in this country, the will...
#        Matching keywords: {'extent', 'statement'}
#
# --- Target: stfeco ---
#   Keywords: {'satisfied', 'economy', 'country', 'overall', 'state', 'current'}
#
#   ⚠️  Potential leakage (9 features):
#      • stflife: overall, how satisfied are you with your life as a whole now...
#        Matching keywords: {'overall', 'satisfied'}
#      • stfdem: overall, how satisfied are you with the way democracy works ...
#        Matching keywords: {'overall', 'satisfied', 'country'}
#      • stfedu: how would you rate the state of education in this country no...
#        Matching keywords: {'state', 'country'}
#      • stfhlth: overall, how would you rate the state of health services in ...
#        Matching keywords: {'overall', 'state', 'country'}
#      • gvbalc19: how well did the government in this country balance protecti...
#        Matching keywords: {'economy', 'country'}
#      • gvhanc19: overall, how satisfied are you with how the government in th...
#        Matching keywords: {'overall', 'satisfied', 'country'}
#      • gvjobc19: how satisfied are you with the government's response in this...
#        Matching keywords: {'satisfied', 'country'}
#      • gveldc19: how satisfied are you with the government's response to the ...
#        Matching keywords: {'satisfied', 'country'}
#      • hscopc19: how satisfied are you with how health services in this count...
#        Matching keywords: {'satisfied', 'country'}
#
# --- Target: impenv ---
#   Keywords: {'important', 'extent', 'should', 'believe', 'after', 'environment', 'apply', 'description', 'nature;', 'looking', 'strongly', 'people'}
#
#   ⚠️  Potential leakage (33 features):
#      • imdfetn: how many immigrants who are a different race or ethnic group...
#        Matching keywords: {'people', 'should'}
#      • hswrk: in the last 7 days, did you do any of the following: housewo...
#        Matching keywords: {'people', 'after'}
#      • hswrkp: in the last 7 days, did your partner do any of the following...
#        Matching keywords: {'looking', 'people', 'after'}
#      • impdiff: how much does this description sound like you: "i like surpr...
#        Matching keywords: {'description', 'important', 'looking'}
#      • imptrad: how well does this description fit you: "tradition is import...
#        Matching keywords: {'description', 'important'}
#      • freehms: to what extent do you agree or disagree with the statement: ...
#        Matching keywords: {'extent', 'should'}
#      • ipcrtiv: how well does this description apply to you: "thinking up ne...
#        Matching keywords: {'apply', 'important', 'description'}
#      • ipfrule: how much does this description sound like you: "this person ...
#        Matching keywords: {'should', 'description', 'people'}
#      • ipmodst: how much does this description describe you: "it's important...
#        Matching keywords: {'description', 'important'}
#      • ipgdtim: how much does this description sound like you: "having a goo...
#        Matching keywords: {'description', 'important'}

# %% [markdown]
# ### Interpreting Leakage Analysis
#
# **If features are being excluded:**
# - Review each exclusion - does it make sense?
# - If too aggressive (excluding unrelated features), raise the threshold
# - If too permissive, lower the threshold
#
# **If nothing is excluded but you expect exclusions:**
# - Check that semantic filtering is enabled
# - Lower the similarity threshold (try 0.5 or 0.6)
# - The questions may be phrased too differently for semantic matching
#
# **For manual review:**
# - Look for questions measuring the same construct with different wording
# - Party vote prediction: exclude party identification, past voting, party closeness
# - Trust questions: watch for batteries of related trust items

# %% [markdown]
# ---
# **Preview Output Formats**
#
# See how profiles look in different prompt formats.

# %%
# Show available formats
print("Available profile formats:")
for fmt in list_profile_formats():
    print(f"  • {fmt}")
# Out:
# Available profile formats:
#   • qa
#   • interview
#   • bullet
#   • colon
#   • arrow
#   • brackets
#   • xml
#   • json
#   • narrative
#   • card

# %%
# Generate a sample instance for format comparison
instance = generator.generate_prediction_instance(
    respondent_id=sample_respondent_id,
    target_code=sample_target,
    n_sections=2,
    m_features_per_section=2,
    seed=42
)

# Preview each format
formats_to_show = ['qa', 'interview', 'bullet', 'arrow', 'brackets', 'json', 'narrative', 'card']

for fmt in formats_to_show:
    print(f"\n{'='*70}")
    print(f"FORMAT: {fmt}")
    print(f"{'='*70}")

    prompt = instance.to_prompt(profile_format=fmt)
    print(prompt)
# Out:
# ======================================================================
# FORMAT: qa
# ======================================================================
# Here is information about a survey respondent:
#
# Q: Do you feel closer to any one political party than to the others?
# A: No
# Q: Where would you place yourself on the political spectrum, from left to right?
# A: Left
# Q: If many people used less energy, how likely is it that would reduce climate change?
# A: Likely
# Q: How likely do you think it is that many people will cut back on their energy use to try to reduce climate change?
# A: Not very likely
#
# Based on this information, please answer:
# What is your gender?
#
# Options:
# 1. Male
# 2. Female
#
# ======================================================================
# FORMAT: interview
# ======================================================================
# Here is information about a survey respondent:
#
# Interviewer: Do you feel closer to any one political party than to the others?
# Respondent: No
# Interviewer: Where would you place yourself on the political spectrum, from left to right?
# Respondent: Left
# Interviewer: If many people used less energy, how likely is it that would reduce climate change?
# Respondent: Likely
# Interviewer: How likely do you think it is that many people will cut back on their energy use to try to reduce climate change?
# Respondent: Not very likely
#
# Based on this information, please answer:
# What is your gender?
#
# Options:
# 1. Male
# 2. Female
#
# ======================================================================
# FORMAT: bullet
# ======================================================================
# Here is information about a survey respondent:
#
# - Do you feel closer to any one political party than to the others?: No
# - Where would you place yourself on the political spectrum, from left to right?: Left
# - If many people used less energy, how likely is it that would reduce climate change?: Likely
# - How likely do you think it is that many people will cut back on their energy use to try to reduce climate change?: Not very likely
#
# Based on this information, please answer:
# What is your gender?
#
# Options:
# 1. Male
# 2. Female
#
# ======================================================================
# FORMAT: arrow
# ======================================================================
# Here is information about a survey respondent:
#
# Do you feel closer to any one political party than to the others? → No
# Where would you place yourself on the political spectrum, from left to right? → Left
# If many people used less energy, how likely is it that would reduce climate change? → Likely
# How likely do you think it is that many people will cut back on their energy use to try to reduce climate change? → Not very likely
#
# Based on this information, please answer:
# What is your gender?
#
# Options:
# 1. Male
# 2. Female
#
# ======================================================================
# FORMAT: brackets
# ======================================================================
# Here is information about a survey respondent:
#
# [Do you feel closer to any one political party than to the others?] No
# [Where would you place yourself on the political spectrum, from left to right?] Left
# [If many people used less energy, how likely is it that would reduce climate change?] Likely
# [How likely do you think it is that many people will cut back on their energy use to try to reduce climate change?] Not very likely
#
# Based on this information, please answer:
# What is your gender?
#
# Options:
# 1. Male
# 2. Female
#
# ======================================================================
# FORMAT: json
# ======================================================================
# Here is information about a survey respondent:
#
# {"q": "Do you feel closer to any one political party than to the others?", "a": "No"}
# {"q": "Where would you place yourself on the political spectrum, from left to right?", "a": "Left"}
# {"q": "If many people used less energy, how likely is it that would reduce climate change?", "a": "Likely"}
# {"q": "How likely do you think it is that many people will cut back on their energy use to try to reduce climate change?", "a": "Not very likely"}
#
# Based on this information, please answer:
# What is your gender?
#
# Options:
# 1. Male
# 2. Female
#
# ======================================================================
# FORMAT: narrative
# ======================================================================
# Here is information about a survey respondent:
#
# When asked "Do you feel closer to any one political party than to the others?", they answered "No".
# When asked "Where would you place yourself on the political spectrum, from left to right?", they answered "Left".
# When asked "If many people used less energy, how likely is it that would reduce climate change?", they answered "Likely".
# When asked "How likely do you think it is that many people will cut back on their energy use to try to reduce climate change?", they answered "Not very likely".
#
# Based on this information, please answer:
# What is your gender?
#
# Options:
# 1. Male
# 2. Female
#
# ======================================================================
# FORMAT: card
# ======================================================================
# Here is information about a survey respondent:
#
# Do you feel closer to any one political party than to the others? | No
# Where would you place yourself on the political spectrum, from left to right? | Left
# If many people used less energy, how likely is it that would reduce climate change? | Likely
# How likely do you think it is that many people will cut back on their energy use to try to reduce climate change? | Not very likely
#
# Based on this information, please answer:
# What is your gender?
#
# Options:
# 1. Male
# 2. Female

# %% [markdown]
# ---
# **Profile Expansion Test**
#
# Test that profile expansion preserves existing features (critical for information richness experiments).

# %%
# Generate base profile
base_instance = generator.generate_prediction_instance(
    respondent_id=sample_respondent_id,
    target_code=sample_target,
    n_sections=1,
    m_features_per_section=2,
    seed=42
)

print("BASE PROFILE (1 section × 2 features):")
print("-" * 50)
for q, a in base_instance.features.items():
    print(f"  • {q[:50]}...")

# Expand profile
expanded_instance = generator.generate_prediction_instance(
    respondent_id=sample_respondent_id,
    target_code=sample_target,
    n_sections=2,
    m_features_per_section=3,
    seed=42  # Same seed!
)

print("\nEXPANDED PROFILE (2 sections × 3 features):")
print("-" * 50)
for q, a in expanded_instance.features.items():
    print(f"  • {q[:50]}...")

# Verify subset relationship
base_questions = set(base_instance.features.keys())
expanded_questions = set(expanded_instance.features.keys())

print("\n" + "=" * 50)
if base_questions.issubset(expanded_questions):
    print("✓ PASS: Base features preserved in expanded profile")
    new_features = expanded_questions - base_questions
    print(f"  New features added: {len(new_features)}")
else:
    print("❌ FAIL: Base features NOT preserved!")
    missing = base_questions - expanded_questions
    print(f"  Missing features: {missing}")
# Out:
# BASE PROFILE (1 section × 2 features):
# --------------------------------------------------
#   • Do you feel closer to any one political party than...
#   • Where would you place yourself on the political sp...
#
# EXPANDED PROFILE (2 sections × 3 features):
# --------------------------------------------------
#   • Do you feel closer to any one political party than...
#   • Where would you place yourself on the political sp...
#   • If many people used less energy, how likely is it ...
#   • How likely do you think it is that many people wil...
#   • How likely is it that enough governments will take...
#
# ==================================================
# ✓ PASS: Base features preserved in expanded profile
#   New features added: 3
# C:\Users\matth\Brown Dropbox\Matthias Roesti\Oxford_LLMs\fork\synthetic_sampling\src\synthetic_sampling\profiles\generator.py:743: UserWarning: Respondent BE_10038: some sections had insufficient valid features after filtering missing values: ['political_affiliation: got 2/3']
#   warnings.warn(

# %% [markdown]
# ---
# **Data-Metadata Alignment Check**
#
# Verify that metadata variables exist in the survey data.

# %%
#@title check metadata alignment
def check_data_metadata_alignment(survey_df: pd.DataFrame, metadata: dict) -> None:
    """Check alignment between survey data columns and metadata variables."""

    metadata_vars = set()
    for section, variables in metadata.items():
        metadata_vars.update(variables.keys())

    data_cols = set(survey_df.columns)

    # Variables in metadata but not in data
    missing_in_data = metadata_vars - data_cols

    # Variables in data but not in metadata
    missing_in_metadata = data_cols - metadata_vars

    # Overlap
    overlap = metadata_vars & data_cols

    print("=" * 60)
    print("DATA-METADATA ALIGNMENT")
    print("=" * 60)
    print(f"\nMetadata variables: {len(metadata_vars)}")
    print(f"Data columns: {len(data_cols)}")
    print(f"Overlap: {len(overlap)} ({100*len(overlap)/len(metadata_vars):.1f}% of metadata)")

    if missing_in_data:
        print(f"\n⚠️  Variables in metadata but NOT in data ({len(missing_in_data)}):")
        for v in sorted(list(missing_in_data))[:20]:
            print(f"   • {v}")
        if len(missing_in_data) > 20:
            print(f"   ... and {len(missing_in_data) - 20} more")

    if len(missing_in_metadata) < 50:  # Only show if not too many
        print(f"\nℹ️  Data columns not in metadata ({len(missing_in_metadata)}):")
        for v in sorted(list(missing_in_metadata))[:10]:
            print(f"   • {v}")


check_data_metadata_alignment(survey_df, metadata)
# Out:
# ============================================================
# DATA-METADATA ALIGNMENT
# ============================================================
#
# Metadata variables: 551
# Data columns: 619
# Overlap: 551 (100.0% of metadata)

# %% [markdown]
# ---
# ## **4. Quality Assurance Checklist**
#
# Use this checklist when reviewing metadata:
#
# ### Structure ✓
# - [ ] All sections are dictionaries
# - [ ] All variables have `description`, `question`, `values` fields
# - [ ] No duplicate variable codes across sections
#
# ### Questions ✓
# - [ ] Questions are natural and conversational
# - [ ] Survey artifacts removed ("looking at card", "interviewer records")
# - [ ] Questions make sense as standalone (without survey context)
# - [ ] Transformations documented in `notes` field where applicable
#
# ### Answer Options ✓
# - [ ] All value codes have text labels (no numeric-only labels)
# - [ ] Likert scales collapsed to ~5 interpretable categories
# - [ ] Missing value categories included (Missing, Refused, Don't know, etc.)
# - [ ] Country-specific options are realistic (e.g., political parties)
#
# ### Thematic Grouping ✓
# - [ ] Variables logically grouped into sections
# - [ ] Section names are descriptive (demographics, political_attitudes, etc.)
# - [ ] Sections are balanced (not one giant section with everything)
#
# ### Data Alignment ✓
# - [ ] Variable codes match column names in survey data
# - [ ] Value codes in metadata match actual values in data

# %% [markdown]
# ---
# ## **5. Export Sample Profiles**
#
# Generate and export sample profiles for review.

# %%
def export_sample_profiles(
    generator: RespondentProfileGenerator,
    survey_df: pd.DataFrame,
    target_codes: list,
    n_samples: int = 5,
    output_path: str = 'sample_profiles.json'
) -> None:
    """
    Export sample prediction instances for manual review.
    """
    np.random.seed(42)

    samples = []
    respondent_ids = survey_df[generator.respondent_id_col].sample(n_samples).tolist()

    for rid in respondent_ids:
        for target in target_codes:
            try:
                instance = generator.generate_prediction_instance(
                    respondent_id=rid,
                    target_code=target,
                    n_sections=2,
                    m_features_per_section=3,
                    seed=42
                )

                # generate_prediction_instance returns None if target answer is missing
                if instance is None:
                    print(f"Warning: Respondent {rid} has missing answer for {target}, skipping")
                    continue

                samples.append({
                    'respondent_id': instance.id,
                    'country': instance.country,
                    'target_code': instance.target_code,
                    'profile': instance.features,
                    'target_question': instance.target_question,
                    'target_options': instance.options,
                    'target_answer': instance.answer,
                    'prompt_qa': instance.to_prompt(profile_format='qa'),
                    'prompt_bullet': instance.to_prompt(profile_format='bullet')
                })
            except Exception as e:
                print(f"Warning: Could not generate for {rid}, {target}: {e}")

    with open(output_path, 'w') as f:
        json.dump(samples, f, indent=2)

    print(f"✓ Exported {len(samples)} sample profiles to {output_path}")


# Export samples
# export_sample_profiles(generator, survey_df, TARGET_CODES, n_samples=5)

# %%
export_sample_profiles(generator, survey_df, TARGET_CODES, n_samples=5)
# Out:
# Warning: Respondent FR_27160 has missing answer for mnactp, skipping
# Warning: Respondent FR_12458 has missing answer for mnactp, skipping
# Warning: Respondent LT_20861 has missing answer for c19mcpnt, skipping
# Warning: Respondent LT_20861 has missing answer for mnactp, skipping
# Warning: Respondent HR_11873 has missing answer for mnactp, skipping
# ✓ Exported 15 sample profiles to sample_profiles.json
